# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from impyute.imputation.cs import mice

# %% [markdown]
# # Data Processing and EDA

# %%
#read in data
all_fund = pd.read_csv('all_companies_fund.csv') #2000-2019
all_bank = pd.read_csv('all_bankruptcies.csv', encoding = "ISO-8859-1") #2000-2019
# Out:
# C:\Users\Joseph\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (2,33,37,955,956,957,962,972,976,977,982) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\Joseph\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (263,341) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#keys to join all databases
key_table = all_fund[['cik', 'GVKEY']] 
key_table = key_table.drop_duplicates()
key_table.head()
# Out:
#          cik  GVKEY
# 0     1750.0   1004
# 19  910627.0   1010
# 23   61478.0   1013
# 34    2668.0   1019
# 36  319126.0   1021

# %%
mask = all_fund['stalt'] == 'TL'
tl = all_fund[mask]
tl
# Out:
#          GVKEY LINKPRIM LIID LINKTYPE  LPERMNO  LPERMCO      LINKDT  \
# 73        1045        P   01       NR      NaN      NaN  01/05/2012
# 473       1164        P   01       NR      NaN      NaN  07/30/2002
# 867       1263        N  01C       NU      NaN      NaN  12/01/2000
# 868       1263        P   01       NR      NaN      NaN  12/01/2000
# 1167      1388        C  00X       NU      NaN      NaN  01/01/1983
# ...        ...      ...  ...      ...      ...      ...         ...
# 236932  273726        P   01       LC  93338.0  53385.0  04/15/2010
# 237802  294524        C  00X       NR      NaN      NaN  01/01/2006
# 237889  296944        N   01       NR      NaN      NaN  01/29/2014
# 237890  296944        P   02       LC  14417.0  54709.0  01/29/2014
# 237905  297209        P   01       NR      NaN      NaN  09/13/2017
#
#          LINKENDDT    datadate   fyear  ... priusa   sic spcindcd spcseccd  \
# 73      11/30/2013  12/31/2012  2012.0  ...    4.0  4512    605.0    600.0
# 473     03/31/2004  12/31/2002  2002.0  ...   10.0  4813    463.0    974.0
# 867     12/31/2001  12/31/2001  2001.0  ...    6.0  3312    460.0    970.0
# 868     01/31/2002  12/31/2001  2001.0  ...    6.0  3312    460.0    970.0
# 1167             E  12/31/2011  2011.0  ...    1.0  4512    605.0    600.0
# ...            ...         ...     ...  ...    ...   ...      ...      ...
# 236932  06/30/2018  12/31/2017  2017.0  ...    2.0  1381      NaN      NaN
# 237802  04/29/2010  12/31/2009  2009.0  ...    1.0  2820      NaN      NaN
# 237889           E  12/31/2017  2017.0  ...    2.0  1381      NaN      NaN
# 237890  07/03/2018  12/31/2017  2017.0  ...    2.0  1381      NaN      NaN
# 237905  12/17/2018  12/31/2017  2017.0  ...    1.0  1381      NaN      NaN
#
#        spcsrc state stko                   weburl       dldte     ipodate
# 73         B-    TX  0.0               www.aa.com         NaN         NaN
# 473       NaN    NJ  0.0  www.wcom.com/home.shtml  01/09/2006         NaN
# 867       NaN    ON  2.0           www.algoma.com         NaN         NaN
# 868       NaN    ON  2.0           www.algoma.com         NaN         NaN
# 1167      NaN    TX  1.0               www.aa.com         NaN         NaN
# ...       ...   ...  ...                      ...         ...         ...
# 236932    NaN   NaN  0.0         www.seadrill.com         NaN  04/15/2010
# 237802     B+   NaN  0.0   www.lyondellbasell.com         NaN         NaN
# 237889    NaN   NaN  3.0         www.nadlcorp.com  07/03/2018         NaN
# 237890    NaN   NaN  3.0         www.nadlcorp.com  07/03/2018         NaN
# 237905    NaN    TX  0.0  www.pacificdrilling.com         NaN  11/11/2011
#
# [788 rows x 988 columns]

# %%
all_fund[all_fund['GVKEY'] == 273726][['datadate','stalt','cik']]
# Out:
#           datadate stalt        cik
# 236923  12/31/2008   NaN  1737706.0
# 236924  12/31/2009   NaN  1737706.0
# 236925  12/31/2010   NaN  1737706.0
# 236926  12/31/2011   NaN  1737706.0
# 236927  12/31/2012   NaN  1737706.0
# 236928  12/31/2013   NaN  1737706.0
# 236929  12/31/2014   NaN  1737706.0
# 236930  12/31/2015   NaN  1737706.0
# 236931  12/31/2016   NaN  1737706.0
# 236932  12/31/2017    TL  1737706.0
# 236933  12/31/2018   NaN  1737706.0
# 236934  12/31/2018   NaN  1737706.0

# %%
all_bank[all_bank['COMPANY_FKEY'] == 1737706]
# Out:
# Empty DataFrame
# Columns: [BANK_KEY, SUBSID_NAME, BANKRUPTCY_TYPE, LAW_COURT_FKEY, COURT_TYPE_CODE, COURT_NAME, COURT_S_NAME, COURT_LOC_STREET, COURT_LOC_CITY, COURT_LOC_STATE, COURT_LOC_ZIP, COURT_LOC, COURT_URL, LAW_COURT_STATE_NAME, LAW_COURT_COUNTRY, LAW_COURT_REG, LAW_COURT_CON_SUPER_REG, BANK_BEGIN_DATE, BANK_END_DATE, FTP_FILE_FKEY, FORM_FKEY, FILE_DATE, FILE_ACCEPTED, FILE_SIZE, HTTP_NAME_HTML, HTTP_NAME_TEXT, COMPANY_FKEY, BEST_EDGAR_TICKER, MATCHQU_PRICE_DATE, MATCHQU_PRICE_CLOSE, MATCHQU_TSO_DATE, MATCHQU_TSO, MATCHQU_TSO_MARKCAP, MATCHQU_DATE_QTR, MATCHQU_DATE_TTM, MATCHQU_FILING_CODE_QTR, MATCHQU_FILING_CODE_TTM, MATCHQU_ANNUAL_QUINDIC, MATCHQU_BALSH_BOOK_VAL, MATCHQU_BALSH_ASSETS, MATCHQU_BALSH_CASH_EQUIVS, MATCHQU_INCMST_REV_QTR, MATCHQU_INCMST_REV_TTM, MATCHQU_INCMST_NETINC_QTR, MATCHQU_INCMST_NETINC_TTM, MATCHQU_INCMST_EXTRAITM_QTR, MATCHQU_INCMST_EXTRAITM_TTM, MATCHQU_INCMST_EBITDA_QTR, MATCHQU_INCMST_EBITDA_TTM, MATCHQU_EFF_ACCCHANGE_QTR, MATCHQU_EFF_ACCCHANGE_TTM, MATCHQU_CSHFLST_OP_ACT_QTR, MATCHQU_CSHFLST_OP_ACT_TTM, MATCHQU_CSHFLST_INV_ACT_QTR, MATCHQU_CSHFLST_INV_ACT_TTM, MATCHQU_CSHFLST_FIN_ACT_QTR, MATCHQU_CSHFLST_FIN_ACT_TTM, MATCHQU_CSHFLST_CHANGE_QTR, MATCHQU_CSHFLST_CHANGE_TTM, PRIORQU_PRICE_DATE, PRIORQU_PRICE_CLOSE, PRIORQU_TSO_DATE, PRIORQU_TSO, PRIORQU_TSO_MARKCAP, PRIORQU_DATE_QTR, PRIORQU_DATE_TTM, PRIORQU_FILING_CODE_QTR, PRIORQU_FILING_CODE_TTM, PRIORQU_ANNUAL_QUINDIC, PRIORQU_BALSH_BOOK_VAL, PRIORQU_BALSH_ASSETS, PRIORQU_BALSH_CASH_EQUIVS, PRIORQU_INCMST_REV_QTR, PRIORQU_INCMST_REV_TTM, PRIORQU_INCMST_NETINC_QTR, PRIORQU_INCMST_NETINC_TTM, PRIORQU_INCMST_EXTRAITM_QTR, PRIORQU_INCMST_EXTRAITM_TTM, PRIORQU_INCMST_EBITDA_QTR, PRIORQU_INCMST_EBITDA_TTM, PRIORQU_EFF_ACCCHANGE_QTR, PRIORQU_EFF_ACCCHANGE_TTM, PRIORQU_CSHFLST_OP_ACT_QTR, PRIORQU_CSHFLST_OP_ACT_TTM, PRIORQU_CSHFLST_INV_ACT_QTR, PRIORQU_CSHFLST_INV_ACT_TTM, PRIORQU_CSHFLST_FIN_ACT_QTR, PRIORQU_CSHFLST_FIN_ACT_TTM, PRIORQU_CSHFLST_CHANGE_QTR, PRIORQU_CSHFLST_CHANGE_TTM, MATCHFY_PRICE_DATE, MATCHFY_PRICE_CLOSE, MATCHFY_TSO_DATE, MATCHFY_TSO, MATCHFY_TSO_MARKCAP, MATCHFY_DATE_QTR, MATCHFY_DATE_TTM, MATCHFY_FILING_CODE_QTR, MATCHFY_FILING_CODE_TTM, MATCHFY_ANNUAL_QUINDIC, ...]
# Index: []
#
# [0 rows x 464 columns]

# %% [markdown]
# ## Bankruptcy Data EDA

# %%
all_bank['BANKRUPTCY_TYPE'].value_counts().plot(kind = 'bar')

# %%
#extract useful information
all_bank = all_bank[['BANKRUPTCY_TYPE', 'BANK_BEGIN_DATE', 'SIC_CODE_FKEY', 'SIC_CODE_DESCRIP', 'NAICS_CODE_DESCRIP', 'NAICS_CODE_FKEY', 'SHORT_NAME', 'NAME', 'COMPANY_FKEY']]

# %%
#top 20 industries with most bankruptcies using SIC code

all_bank['SIC_CODE_DESCRIP'].value_counts(ascending = False)[:20].plot(kind = 'bar', figsize = (15,8))

# %%
#top 20 industries with most bankruptcies using NICS code

all_bank['NAICS_CODE_DESCRIP'].value_counts(ascending = False)[:20].plot(kind = 'bar', figsize = (15,8))

# %%
all_bank['year'] = pd.to_datetime(all_bank['BANK_BEGIN_DATE']).dt.year
all_bank['year'].value_counts().sort_index().plot(kind = 'bar', figsize = (10,5))

# %%
# gvkey_list = str(list(all_fund['GVKEY'].unique())).strip('\'').strip('[').strip(']').split(', ')

# # Write to txt file to look up relevant companies in Audit Analytics database
# # file = open('all_GVKEY.txt','w')
# # for i in all_fund['GVKEY']:
# #     file.write(str(i))
# #     file.write('\n')
# # file.close()

print(all_fund['GVKEY'].nunique(), 'of unique GVKEYs')
print(all_fund['cik'].nunique(), 'of unique ciks')
print('cik is the only way to join to bankruptcy data, might explain why so many bankruptcies were dropped')
# Out:
# 24933 of unique GVKEYs
# 17998 of unique ciks
# cik is the only way to join to bankruptcy data, might explain why so many bankruptcies were dropped

# %%
# all_bank.groupby(['year', 'NAICS_CODE_DESCRIP'])[['NAICS_CODE_DESCRIP']].count().unstack().to_csv('industrybank.csv')

# %%
# all_bank.groupby(['year', 'SIC_CODE_DESCRIP'])[['NAICS_CODE_DESCRIP']].count().unstack().to_csv('sicbank.csv')

# %%
all_bank.shape
# Out:
# (2779, 10)

# %%
f_keys = list(all_bank['COMPANY_FKEY'])

# %%
ciks = list(key_table['cik'])

# %%
#test how many bankrupt Fkeys are in fundamental
x = [] 
for i in f_keys:
    
    if i in ciks:
        continue
    
    else:
        x.append(i)
        print (i, 'not in fundamental')
# Out:
# 3662 not in fundamental
# 3941 not in fundamental
# 4707 not in fundamental
# 5588 not in fundamental
# 6948 not in fundamental
# 8109 not in fundamental
# 12105 not in fundamental
# 13156 not in fundamental
# 18530 not in fundamental
# 23778 not in fundamental
# 23778 not in fundamental
# 27960 not in fundamental
# 28761 not in fundamental
# 30419 not in fundamental
# 30419 not in fundamental
# 34879 not in fundamental
# 40730 not in fundamental
# 43960 not in fundamental
# 45791 not in fundamental
# 46601 not in fundamental
# 47968 not in fundamental
# 53453 not in fundamental
# 56824 not in fundamental
# 57201 not in fundamental
# 59401 not in fundamental
# 60064 not in fundamental
# 60064 not in fundamental
# 65202 not in fundamental
# 67199 not in fundamental
# 70412 not in fundamental
# 72655 not in fundamental
# 75234 not in fundamental
# 76741 not in fundamental
# 79839 not in fundamental
# 82925 not in fundamental
# 87888 not in fundamental
# 94026 not in fundamental
# 94601 not in fundamental
# 96294 not in fundamental
# 97579 not in fundamental
# 99321 not in fundamental
# 100817 not in fundamental
# 100979 not in fundamental
# 105107 not in fundamental
# 202890 not in fundamental
# 217165 not in fundamental
# 278327 not in fundamental
# 312840 not in fundamental
# 316236 not in fundamental
# 316621 not in fundamental
# 316643 not in fundamental
# 318262 not in fundamental
# 319237 not in fundamental
# 320515 not in fundamental
# 350305 not in fundamental
# 350524 not in fundamental
# 350920 not in fundamental
# 351127 not in fundamental
# 354699 not in fundamental
# 355701 not in fundamental
# 356395 not in fundamental
# 356395 not in fundamental
# 701856 not in fundamental
# 714560 not in fundamental
# 719241 not in fundamental
# 719662 not in fundamental
# 722487 not in fundamental
# 725151 not in fundamental
# 725395 not in fundamental
# 726608 not in fundamental
# 727742 not in fundamental
# 728586 not in fundamental
# 730169 not in fundamental
# 737762 not in fundamental
# 739708 not in fundamental
# 743029 not in fundamental
# 743368 not in fundamental
# 744667 not in fundamental
# 745167 not in fundamental
# 748210 not in fundamental
# 750274 not in fundamental
# 750339 not in fundamental
# 760497 not in fundamental
# 764763 not in fundamental
# 766738 not in fundamental
# 768957 not in fundamental
# 769591 not in fundamental
# 769852 not in fundamental
# 770471 not in fundamental
# 771176 not in fundamental
# 771934 not in fundamental
# 773603 not in fundamental
# 773724 not in fundamental
# 773937 not in fundamental
# 774492 not in fundamental
# 778161 not in fundamental
# 778438 not in fundamental
# 779033 not in fundamental
# 780118 not in fundamental
# 780882 not in fundamental
# 781889 not in fundamental
# 783211 not in fundamental
# 785080 not in fundamental
# 785814 not in fundamental
# 785962 not in fundamental
# 786343 not in fundamental
# 789878 not in fundamental
# 792341 not in fundamental
# 797329 not in fundamental
# 797556 not in fundamental
# 798539 not in fundamental
# 798952 not in fundamental
# 799197 not in fundamental
# 800401 not in fundamental
# 804154 not in fundamental
# 805956 not in fundamental
# 808207 not in fundamental
# 808713 not in fundamental
# 813347 not in fundamental
# 814249 not in fundamental
# 818467 not in fundamental
# 818808 not in fundamental
# 818815 not in fundamental
# 819690 not in fundamental
# 819818 not in fundamental
# 819975 not in fundamental
# 820408 not in fundamental
# 823927 not in fundamental
# 826743 not in fundamental
# 829764 not in fundamental
# 830821 not in fundamental
# 832922 not in fundamental
# 839437 not in fundamental
# 841123 not in fundamental
# 841866 not in fundamental
# 842010 not in fundamental
# 842807 not in fundamental
# 843650 not in fundamental
# 844055 not in fundamental
# 845874 not in fundamental
# 845879 not in fundamental
# 846899 not in fundamental
# 847468 not in fundamental
# 849862 not in fundamental
# 851292 not in fundamental
# 853271 not in fundamental
# 854171 not in fundamental
# 855575 not in fundamental
# 855581 not in fundamental
# 858395 not in fundamental
# 859916 not in fundamental
# 860131 not in fundamental
# 861955 not in fundamental
# 862026 not in fundamental
# 864902 not in fundamental
# 866491 not in fundamental
# 866492 not in fundamental
# 866751 not in fundamental
# 867443 not in fundamental
# 867572 not in fundamental
# 868016 not in fundamental
# 868076 not in fundamental
# 869494 not in fundamental
# 869498 not in fundamental
# 870398 not in fundamental
# 871696 not in fundamental
# 873601 not in fundamental
# 874212 not in fundamental
# 874787 not in fundamental
# 875612 not in fundamental
# 875942 not in fundamental
# 876320 not in fundamental
# 878324 not in fundamental
# 878543 not in fundamental
# 879385 not in fundamental
# 879774 not in fundamental
# 879969 not in fundamental
# 880034 not in fundamental
# 882259 not in fundamental
# 883558 not in fundamental
# 884321 not in fundamental
# 884403 not in fundamental
# 885566 not in fundamental
# 886113 not in fundamental
# 887356 not in fundamental
# 889571 not in fundamental
# 890081 not in fundamental
# 890284 not in fundamental
# 890925 not in fundamental
# 891533 not in fundamental
# 891537 not in fundamental
# 892604 not in fundamental
# 893670 not in fundamental
# 894232 not in fundamental
# 894417 not in fundamental
# 894503 not in fundamental
# 894535 not in fundamental
# 894544 not in fundamental
# 894789 not in fundamental
# 895648 not in fundamental
# 895659 not in fundamental
# 895716 not in fundamental
# 896145 not in fundamental
# 897745 not in fundamental
# 898802 not in fundamental
# 898904 not in fundamental
# 899164 not in fundamental
# 899823 not in fundamental
# 902787 not in fundamental
# 904080 not in fundamental
# 904344 not in fundamental
# 906196 not in fundamental
# 906347 not in fundamental
# 909963 not in fundamental
# 910133 not in fundamental
# 910468 not in fundamental
# 910639 not in fundamental
# 910719 not in fundamental
# 911221 not in fundamental
# 911522 not in fundamental
# 911566 not in fundamental
# 912952 not in fundamental
# 913015 not in fundamental
# 913034 not in fundamental
# 915354 not in fundamental
# 915390 not in fundamental
# 916104 not in fundamental
# 916106 not in fundamental
# 916109 not in fundamental
# 916184 not in fundamental
# 917464 not in fundamental
# 918963 not in fundamental
# 919226 not in fundamental
# 919603 not in fundamental
# 919957 not in fundamental
# 919999 not in fundamental
# 920042 not in fundamental
# 920317 not in fundamental
# 920317 not in fundamental
# 921445 not in fundamental
# 921929 not in fundamental
# 924117 not in fundamental
# 924374 not in fundamental
# 924380 not in fundamental
# 925942 not in fundamental
# 927456 not in fundamental
# 927643 not in fundamental
# 927760 not in fundamental
# 927790 not in fundamental
# 927809 not in fundamental
# 928156 not in fundamental
# 928800 not in fundamental
# 929144 not in fundamental
# 929941 not in fundamental
# 930529 not in fundamental
# 931085 not in fundamental
# 934330 not in fundamental
# 934852 not in fundamental
# 934873 not in fundamental
# 935730 not in fundamental
# 935802 not in fundamental
# 936163 not in fundamental
# 937603 not in fundamental
# 941020 not in fundamental
# 941552 not in fundamental
# 943206 not in fundamental
# 943322 not in fundamental
# 943323 not in fundamental
# 943690 not in fundamental
# 944402 not in fundamental
# 944649 not in fundamental
# 944853 not in fundamental
# 945212 not in fundamental
# 946154 not in fundamental
# 946283 not in fundamental
# 947425 not in fundamental
# 947429 not in fundamental
# 948073 not in fundamental
# 948590 not in fundamental
# 948945 not in fundamental
# 949493 not in fundamental
# 1000285 not in fundamental
# 1001131 not in fundamental
# 1001430 not in fundamental
# 1002130 not in fundamental
# 1002131 not in fundamental
# 1002628 not in fundamental
# 1003479 not in fundamental
# 1004232 not in fundamental
# 1004967 not in fundamental
# 1005653 not in fundamental
# 1005858 not in fundamental
# 1007588 not in fundamental
# 1008882 not in fundamental
# 1009403 not in fundamental
# 1009479 not in fundamental
# 1009618 not in fundamental
# 1010141 not in fundamental
# 1011108 not in fundamental
# 1011308 not in fundamental
# 1011630 not in fundamental
# 1012176 not in fundamental
# 1012316 not in fundamental
# 1013240 not in fundamental
# 1013453 not in fundamental
# 1013608 not in fundamental
# 1013610 not in fundamental
# 1013740 not in fundamental
# 1013787 not in fundamental
# 1015535 not in fundamental
# 1015611 not in fundamental
# 1015611 not in fundamental
# 1015629 not in fundamental
# 1015979 not in fundamental
# 1016694 not in fundamental
# 1016741 not in fundamental
# 1016900 not in fundamental
# 1017616 not in fundamental
# 1017916 not in fundamental
# 1018675 not in fundamental
# 1019285 not in fundamental
# 1020389 not in fundamental
# 1021294 not in fundamental
# 1021352 not in fundamental
# 1021549 not in fundamental
# 1021649 not in fundamental
# 1021706 not in fundamental
# 1022494 not in fundamental
# 1022832 not in fundamental
# 1023294 not in fundamental
# 1023339 not in fundamental
# 1024109 not in fundamental
# 1024678 not in fundamental
# 1025566 not in fundamental
# 1025950 not in fundamental
# 1025966 not in fundamental
# 1026304 not in fundamental
# 1026486 not in fundamental
# 1027377 not in fundamental
# 1027574 not in fundamental
# 1027878 not in fundamental
# 1028079 not in fundamental
# 1028985 not in fundamental
# 1029140 not in fundamental
# 1029182 not in fundamental
# 1029253 not in fundamental
# 1029532 not in fundamental
# 1029850 not in fundamental
# 1030108 not in fundamental
# 1030776 not in fundamental
# 1030906 not in fundamental
# 1031176 not in fundamental
# 1031425 not in fundamental
# 1031827 not in fundamental
# 1031999 not in fundamental
# 1033671 not in fundamental
# 1033926 not in fundamental
# 1034415 not in fundamental
# 1035118 not in fundamental
# 1035270 not in fundamental
# 1036075 not in fundamental
# 1036283 not in fundamental
# 1036297 not in fundamental
# 1037070 not in fundamental
# 1037927 not in fundamental
# 1038370 not in fundamental
# 1038800 not in fundamental
# 1039500 not in fundamental
# 1039646 not in fundamental
# 1040597 not in fundamental
# 1041077 not in fundamental
# 1041454 not in fundamental
# 1041645 not in fundamental
# 1041895 not in fundamental
# 1041970 not in fundamental
# 1042078 not in fundamental
# 1042420 not in fundamental
# 1042582 not in fundamental
# 1043119 not in fundamental
# 1043438 not in fundamental
# 1043497 not in fundamental
# 1044440 not in fundamental
# 1044583 not in fundamental
# 1044649 not in fundamental
# 1045550 not in fundamental
# 1045703 not in fundamental
# 1046356 not in fundamental
# 1046777 not in fundamental
# 1047153 not in fundamental
# 1047368 not in fundamental
# 1047860 not in fundamental
# 1048845 not in fundamental
# 1049618 not in fundamental
# 1049620 not in fundamental
# 1049889 not in fundamental
# 1050119 not in fundamental
# 1050835 not in fundamental
# 1051254 not in fundamental
# 1051381 not in fundamental
# 1052245 not in fundamental
# 1054524 not in fundamental
# 1054748 not in fundamental
# 1054992 not in fundamental
# 1055131 not in fundamental
# 1055684 not in fundamental
# 1056286 not in fundamental
# 1057725 not in fundamental
# 1057827 not in fundamental
# 1057831 not in fundamental
# 1057834 not in fundamental
# 1057836 not in fundamental
# 1058627 not in fundamental
# 1058628 not in fundamental
# 1058629 not in fundamental
# 1058631 not in fundamental
# 1058767 not in fundamental
# 1058956 not in fundamental
# 1059363 not in fundamental
# 1059364 not in fundamental
# 1059567 not in fundamental
# 1059570 not in fundamental
# 1059572 not in fundamental
# 1059573 not in fundamental
# 1059576 not in fundamental
# 1059706 not in fundamental
# 1059838 not in fundamental
# 1059888 not in fundamental
# 1060242 not in fundamental
# 1060356 not in fundamental
# 1060791 not in fundamental
# 1060948 not in fundamental
# 1060951 not in fundamental
# 1061103 not in fundamental
# 1061103 not in fundamental
# 1061164 not in fundamental
# 1061499 not in fundamental
# 1061701 not in fundamental
# 1061800 not in fundamental
# 1061822 not in fundamental
# 1062312 not in fundamental
# 1062485 not in fundamental
# 1062565 not in fundamental
# 1062829 not in fundamental
# 1062834 not in fundamental
# 1063262 not in fundamental
# 1063326 not in fundamental
# 1063842 not in fundamental
# 1063921 not in fundamental
# 1064049 not in fundamental
# 1064133 not in fundamental
# 1064526 not in fundamental
# 1064527 not in fundamental
# 1065001 not in fundamental
# 1065310 not in fundamental
# 1065493 not in fundamental
# 1065663 not in fundamental
# 1065983 not in fundamental
# 1066048 not in fundamental
# 1066759 not in fundamental
# 1066797 not in fundamental
# 1066928 not in fundamental
# 1067064 not in fundamental
# 1067125 not in fundamental
# 1067310 not in fundamental
# 1067331 not in fundamental
# 1067356 not in fundamental
# 1067447 not in fundamental
# 1067636 not in fundamental
# 1068052 not in fundamental
# 1068078 not in fundamental
# 1068660 not in fundamental
# 1068874 not in fundamental
# 1069003 not in fundamental
# 1070313 not in fundamental
# 1070510 not in fundamental
# 1070669 not in fundamental
# 1071411 not in fundamental
# 1071645 not in fundamental
# 1072229 not in fundamental
# 1072342 not in fundamental
# 1073091 not in fundamental
# 1073715 not in fundamental
# 1074457 not in fundamental
# 1074663 not in fundamental
# 1075043 not in fundamental
# 1076647 not in fundamental
# 1076700 not in fundamental
# 1077030 not in fundamental
# 1077597 not in fundamental
# 1078006 not in fundamental
# 1078392 not in fundamental
# 1078420 not in fundamental
# 1078547 not in fundamental
# 1078593 not in fundamental
# 1078706 not in fundamental
# 1079250 not in fundamental
# 1079791 not in fundamental
# 1080504 not in fundamental
# 1080558 not in fundamental
# 1081074 not in fundamental
# 1081192 not in fundamental
# 1081748 not in fundamental
# 1081938 not in fundamental
# 1082129 not in fundamental
# 1082292 not in fundamental
# 1082699 not in fundamental
# 1083198 not in fundamental
# 1083661 not in fundamental
# 1083914 not in fundamental
# 1084465 not in fundamental
# 1084486 not in fundamental
# 1084873 not in fundamental
# 1085319 not in fundamental
# 1085320 not in fundamental
# 1085475 not in fundamental
# 1085476 not in fundamental
# 1086385 not in fundamental
# 1086620 not in fundamental
# 1086637 not in fundamental
# 1087008 not in fundamental
# 1087328 not in fundamental
# 1088316 not in fundamental
# 1088464 not in fundamental
# 1088815 not in fundamental
# 1088914 not in fundamental
# 1089450 not in fundamental
# 1089451 not in fundamental
# 1089708 not in fundamental
# 1089775 not in fundamental
# 1089851 not in fundamental
# 1089853 not in fundamental
# 1089854 not in fundamental
# 1091492 not in fundamental
# 1091535 not in fundamental
# 1092233 not in fundamental
# 1092302 not in fundamental
# 1093942 not in fundamental
# 1094983 not in fundamental
# 1095102 not in fundamental
# 1095827 not in fundamental
# 1096052 not in fundamental
# 1096132 not in fundamental
# 1096353 not in fundamental
# 1096354 not in fundamental
# 1096789 not in fundamental
# 1097335 not in fundamental
# 1097570 not in fundamental
# 1097575 not in fundamental
# 1098016 not in fundamental
# 1098278 not in fundamental
# 1098311 not in fundamental
# 1098430 not in fundamental
# 1098481 not in fundamental
# 1098560 not in fundamental
# 1098692 not in fundamental
# 1098844 not in fundamental
# 1098923 not in fundamental
# 1098949 not in fundamental
# 1099231 not in fundamental
# 1100592 not in fundamental
# 1100674 not in fundamental
# 1100954 not in fundamental
# 1101092 not in fundamental
# 1101137 not in fundamental
# 1102119 not in fundamental
# 1102217 not in fundamental
# 1102283 not in fundamental
# 1102423 not in fundamental
# 1102440 not in fundamental
# 1102546 not in fundamental
# 1103137 not in fundamental
# 1103776 not in fundamental
# 1103993 not in fundamental
# 1104041 not in fundamental
# 1104219 not in fundamental
# 1105055 not in fundamental
# 1106836 not in fundamental
# 1107343 not in fundamental
# 1107802 not in fundamental
# 1107947 not in fundamental
# 1107978 not in fundamental
# 1108088 not in fundamental
# 1108703 not in fundamental
# 1108730 not in fundamental
# 1108943 not in fundamental
# 1108955 not in fundamental
# 1109329 not in fundamental
# 1109664 not in fundamental
# 1109664 not in fundamental
# 1110128 not in fundamental
# 1110441 not in fundamental
# 1111697 not in fundamental
# 1112319 not in fundamental
# 1112437 not in fundamental
# 1112519 not in fundamental
# 1112999 not in fundamental
# 1113053 not in fundamental
# 1113054 not in fundamental
# 1113129 not in fundamental
# 1113806 not in fundamental
# 1114605 not in fundamental
# 1114654 not in fundamental
# 1114676 not in fundamental
# 1114908 not in fundamental
# 1114937 not in fundamental
# 1115841 not in fundamental
# 1115896 not in fundamental
# 1116262 not in fundamental
# 1116563 not in fundamental
# 1116694 not in fundamental
# 1117258 not in fundamental
# 1117922 not in fundamental
# 1117922 not in fundamental
# 1119190 not in fundamental
# 1119664 not in fundamental
# 1120817 not in fundamental
# 1121026 not in fundamental
# 1121745 not in fundamental
# 1121806 not in fundamental
# 1121884 not in fundamental
# 1121886 not in fundamental
# 1122101 not in fundamental
# 1122106 not in fundamental
# 1122887 not in fundamental
# 1123195 not in fundamental
# 1123448 not in fundamental
# 1123606 not in fundamental
# 1123845 not in fundamental
# 1123864 not in fundamental
# 1124289 not in fundamental
# 1124566 not in fundamental
# 1125532 not in fundamental
# 1125892 not in fundamental
# 1127269 not in fundamental
# 1127342 not in fundamental
# 1127358 not in fundamental
# 1127360 not in fundamental
# 1127362 not in fundamental
# 1127783 not in fundamental
# 1128709 not in fundamental
# 1129695 not in fundamental
# 1130013 not in fundamental
# 1130128 not in fundamental
# 1132590 not in fundamental
# 1133494 not in fundamental
# 1134016 not in fundamental
# 1137157 not in fundamental
# 1137239 not in fundamental
# 1137435 not in fundamental
# 1137778 not in fundamental
# 1138173 not in fundamental
# 1138258 not in fundamental
# 1138659 not in fundamental
# 1138862 not in fundamental
# 1139029 not in fundamental
# 1139184 not in fundamental
# 1139198 not in fundamental
# 1140298 not in fundamental
# 1140472 not in fundamental
# 1140586 not in fundamental
# 1140761 not in fundamental
# 1140761 not in fundamental
# 1141395 not in fundamental
# 1142488 not in fundamental
# 1143566 not in fundamental
# 1144834 not in fundamental
# 1145330 not in fundamental
# 1145331 not in fundamental
# 1145332 not in fundamental
# 1145333 not in fundamental
# 1145334 not in fundamental
# 1156216 not in fundamental
# 1156218 not in fundamental
# 1156220 not in fundamental
# 1156221 not in fundamental
# 1157443 not in fundamental
# 1157516 not in fundamental
# 1157564 not in fundamental
# 1159544 not in fundamental
# 1160294 not in fundamental
# 1160437 not in fundamental
# 1161625 not in fundamental
# 1162298 not in fundamental
# 1162721 not in fundamental
# 1163913 not in fundamental
# 1164086 not in fundamental
# 1164123 not in fundamental
# 1166239 not in fundamental
# 1166365 not in fundamental
# 1166414 not in fundamental
# 1167370 not in fundamental
# 1168454 not in fundamental
# 1170016 not in fundamental
# 1170161 not in fundamental
# 1170218 not in fundamental
# 1171017 not in fundamental
# 1171675 not in fundamental
# 1171749 not in fundamental
# 1172371 not in fundamental
# 1172939 not in fundamental
# 1173313 not in fundamental
# 1173738 not in fundamental
# 1175028 not in fundamental
# 1176325 not in fundamental
# 1176435 not in fundamental
# 1176967 not in fundamental
# 1178537 not in fundamental
# 1178539 not in fundamental
# 1178541 not in fundamental
# 1178543 not in fundamental
# 1180186 not in fundamental
# 1180743 not in fundamental
# 1181920 not in fundamental
# 1191119 not in fundamental
# 1194424 not in fundamental
# 1200715 not in fundamental
# 1200718 not in fundamental
# 1200745 not in fundamental
# 1200748 not in fundamental
# 1200752 not in fundamental
# 1201259 not in fundamental
# 1205181 not in fundamental
# 1207856 not in fundamental
# 1208833 not in fundamental
# 1210036 not in fundamental
# 1210936 not in fundamental
# 1215942 not in fundamental
# 1216462 not in fundamental
# 1216964 not in fundamental
# 1219097 not in fundamental
# 1223667 not in fundamental
# 1224923 not in fundamental
# 1226932 not in fundamental
# 1227728 not in fundamental
# 1230489 not in fundamental
# 1238289 not in fundamental
# 1244041 not in fundamental
# 1244087 not in fundamental
# 1252956 not in fundamental
# 1255107 not in fundamental
# 1256582 not in fundamental
# 1257296 not in fundamental
# 1265238 not in fundamental
# 1265239 not in fundamental
# 1265241 not in fundamental
# 1265242 not in fundamental
# 1265243 not in fundamental
# 1265244 not in fundamental
# 1265245 not in fundamental
# 1265251 not in fundamental
# 1265253 not in fundamental
# 1265254 not in fundamental
# 1265255 not in fundamental
# 1265256 not in fundamental
# 1265259 not in fundamental
# 1265260 not in fundamental
# 1265262 not in fundamental
# 1265263 not in fundamental
# 1265264 not in fundamental
# 1265265 not in fundamental
# 1265266 not in fundamental
# 1265267 not in fundamental
# 1265268 not in fundamental
# 1265269 not in fundamental
# 1265271 not in fundamental
# 1265273 not in fundamental
# 1265274 not in fundamental
# 1265275 not in fundamental
# 1265275 not in fundamental
# 1265276 not in fundamental
# 1265283 not in fundamental
# 1265284 not in fundamental
# 1265319 not in fundamental
# 1265319 not in fundamental
# 1266604 not in fundamental
# 1266605 not in fundamental
# 1269022 not in fundamental
# 1270597 not in fundamental
# 1271833 not in fundamental
# 1271834 not in fundamental
# 1274055 not in fundamental
# 1276477 not in fundamental
# 1276676 not in fundamental
# 1281629 not in fundamental
# 1283810 not in fundamental
# 1283825 not in fundamental
# 1283826 not in fundamental
# 1283829 not in fundamental
# 1283834 not in fundamental
# 1283834 not in fundamental
# 1284453 not in fundamental
# 1285206 not in fundamental
# 1286382 not in fundamental
# 1287152 not in fundamental
# 1287159 not in fundamental
# 1287164 not in fundamental
# 1287900 not in fundamental
# 1288361 not in fundamental
# 1288407 not in fundamental
# 1289255 not in fundamental
# 1289370 not in fundamental
# 1289480 not in fundamental
# 1293377 not in fundamental
# 1293379 not in fundamental
# 1293385 not in fundamental
# 1294148 not in fundamental
# 1294208 not in fundamental
# 1294371 not in fundamental
# 1294476 not in fundamental
# 1296595 not in fundamental
# 1296937 not in fundamental
# 1300744 not in fundamental
# 1302502 not in fundamental
# 1302977 not in fundamental
# 1304588 not in fundamental
# 1305464 not in fundamental
# 1305468 not in fundamental
# 1305748 not in fundamental
# 1307697 not in fundamental
# 1309126 not in fundamental
# 1309237 not in fundamental
# 1309499 not in fundamental
# 1310527 not in fundamental
# 1311953 not in fundamental
# 1314361 not in fundamental
# 1314642 not in fundamental
# 1319842 not in fundamental
# 1319845 not in fundamental
# 1319855 not in fundamental
# 1320459 not in fundamental
# 1320460 not in fundamental
# 1320462 not in fundamental
# 1320463 not in fundamental
# 1320465 not in fundamental
# 1320467 not in fundamental
# 1320468 not in fundamental
# 1320475 not in fundamental
# 1320476 not in fundamental
# 1320477 not in fundamental
# 1321099 not in fundamental
# 1322069 not in fundamental
# 1322070 not in fundamental
# 1322071 not in fundamental
# 1322088 not in fundamental
# 1322094 not in fundamental
# 1322096 not in fundamental
# 1322097 not in fundamental
# 1322100 not in fundamental
# 1322101 not in fundamental
# 1322104 not in fundamental
# 1322105 not in fundamental
# 1322106 not in fundamental
# 1322107 not in fundamental
# 1322108 not in fundamental
# 1322110 not in fundamental
# 1322112 not in fundamental
# 1322113 not in fundamental
# 1322115 not in fundamental
# 1322115 not in fundamental
# 1322116 not in fundamental
# 1322117 not in fundamental
# 1322118 not in fundamental
# 1322120 not in fundamental
# 1322122 not in fundamental
# 1322123 not in fundamental
# 1322127 not in fundamental
# 1322129 not in fundamental
# 1322131 not in fundamental
# 1322132 not in fundamental
# 1322133 not in fundamental
# 1322134 not in fundamental
# 1322138 not in fundamental
# 1322139 not in fundamental
# 1322141 not in fundamental
# 1322142 not in fundamental
# 1322144 not in fundamental
# 1322145 not in fundamental
# 1322146 not in fundamental
# 1322147 not in fundamental
# 1322148 not in fundamental
# 1322149 not in fundamental
# 1322150 not in fundamental
# 1322151 not in fundamental
# 1322153 not in fundamental
# 1322154 not in fundamental
# 1322155 not in fundamental
# 1322156 not in fundamental
# 1322157 not in fundamental
# 1322158 not in fundamental
# 1322159 not in fundamental
# 1322161 not in fundamental
# 1322162 not in fundamental
# 1322167 not in fundamental
# 1322168 not in fundamental
# 1322173 not in fundamental
# 1322175 not in fundamental
# 1322178 not in fundamental
# 1322179 not in fundamental
# 1322180 not in fundamental
# 1322182 not in fundamental
# 1322184 not in fundamental
# 1322186 not in fundamental
# 1322187 not in fundamental
# 1322188 not in fundamental
# 1322189 not in fundamental
# 1322190 not in fundamental
# 1322192 not in fundamental
# 1322196 not in fundamental
# 1322200 not in fundamental
# 1322203 not in fundamental
# 1322207 not in fundamental
# 1322226 not in fundamental
# 1322230 not in fundamental
# 1322234 not in fundamental
# 1322236 not in fundamental
# 1322238 not in fundamental
# 1322240 not in fundamental
# 1322244 not in fundamental
# 1322246 not in fundamental
# 1322248 not in fundamental
# 1322249 not in fundamental
# 1322250 not in fundamental
# 1322251 not in fundamental
# 1322253 not in fundamental
# 1322255 not in fundamental
# 1323543 not in fundamental
# 1324477 not in fundamental
# 1326531 not in fundamental
# 1326686 not in fundamental
# 1326688 not in fundamental
# 1328910 not in fundamental
# 1329184 not in fundamental
# 1329605 not in fundamental
# 1330340 not in fundamental
# 1332412 not in fundamental
# 1334914 not in fundamental
# 1335104 not in fundamental
# 1335236 not in fundamental
# 1335288 not in fundamental
# 1336339 not in fundamental
# 1337913 not in fundamental
# 1341293 not in fundamental
# 1341497 not in fundamental
# 1341853 not in fundamental
# 1342514 not in fundamental
# 1342643 not in fundamental
# 1343360 not in fundamental
# 1343611 not in fundamental
# 1343881 not in fundamental
# 1343957 not in fundamental
# 1345059 not in fundamental
# 1346222 not in fundamental
# 1346526 not in fundamental
# 1349120 not in fundamental
# 1351413 not in fundamental
# 1351667 not in fundamental
# 1356505 not in fundamental
# 1357062 not in fundamental
# 1357361 not in fundamental
# 1358057 not in fundamental
# 1360849 not in fundamental
# 1360849 not in fundamental
# 1362659 not in fundamental
# 1362659 not in fundamental
# 1363033 not in fundamental
# 1363346 not in fundamental
# 1364796 not in fundamental
# 1366909 not in fundamental
# 1366913 not in fundamental
# 1367387 not in fundamental
# 1368147 not in fundamental
# 1368154 not in fundamental
# 1368154 not in fundamental
# 1368218 not in fundamental
# 1369233 not in fundamental
# 1370512 not in fundamental
# 1372175 not in fundamental
# 1374835 not in fundamental
# 1374985 not in fundamental
# 1375083 not in fundamental
# 1375424 not in fundamental
# 1376502 not in fundamental
# 1376912 not in fundamental
# 1378670 not in fundamental
# 1379763 not in fundamental
# 1379926 not in fundamental
# 1382056 not in fundamental
# 1382805 not in fundamental
# 1385542 not in fundamental
# 1386026 not in fundamental
# 1386927 not in fundamental
# 1387156 not in fundamental
# 1387371 not in fundamental
# 1389053 not in fundamental
# 1390630 not in fundamental
# 1393614 not in fundamental
# 1395864 not in fundamental
# 1396426 not in fundamental
# 1397346 not in fundamental
# 1397396 not in fundamental
# 1398201 not in fundamental
# 1399311 not in fundamental
# 1399541 not in fundamental
# 1399542 not in fundamental
# 1400122 not in fundamental
# 1400428 not in fundamental
# 1401300 not in fundamental
# 1403053 not in fundamental
# 1403433 not in fundamental
# 1404831 not in fundamental
# 1404834 not in fundamental
# 1404839 not in fundamental
# 1404940 not in fundamental
# 1405041 not in fundamental
# 1405424 not in fundamental
# 1406223 not in fundamental
# 1406868 not in fundamental
# 1407698 not in fundamental
# 1407703 not in fundamental
# 1407805 not in fundamental
# 1410177 not in fundamental
# 1411272 not in fundamental
# 1411286 not in fundamental
# 1411374 not in fundamental
# 1411851 not in fundamental
# 1412030 not in fundamental
# 1412193 not in fundamental
# 1413142 not in fundamental
# 1414367 not in fundamental
# 1416712 not in fundamental
# 1421105 not in fundamental
# 1421732 not in fundamental
# 1423239 not in fundamental
# 1424328 not in fundamental
# 1425319 not in fundamental
# 1426082 not in fundamental
# 1428059 not in fundamental
# 1429331 not in fundamental
# 1429896 not in fundamental
# 1430441 not in fundamental
# 1430996 not in fundamental
# 1431559 not in fundamental
# 1431654 not in fundamental
# 1432244 not in fundamental
# 1432985 not in fundamental
# 1432987 not in fundamental
# 1433833 not in fundamental
# 1434893 not in fundamental
# 1436164 not in fundamental
# 1436222 not in fundamental
# 1436329 not in fundamental
# 1437073 not in fundamental
# 1439600 not in fundamental
# 1443002 not in fundamental
# 1443593 not in fundamental
# 1443818 not in fundamental
# 1445146 not in fundamental
# 1448064 not in fundamental
# 1449491 not in fundamental
# 1449709 not in fundamental
# 1450074 not in fundamental
# 1452206 not in fundamental
# 1454238 not in fundamental
# 1456455 not in fundamental
# 1457737 not in fundamental
# 1465872 not in fundamental
# 1487561 not in fundamental
# 1493587 not in fundamental
# 1497814 not in fundamental
# 1501732 not in fundamental
# 1503813 not in fundamental
# 1508677 not in fundamental
# 1512369 not in fundamental
# 1514443 not in fundamental
# 1518403 not in fundamental
# 1521847 not in fundamental
# 1526948 not in fundamental
# 1536256 not in fundamental
# 1541354 not in fundamental
# 1551510 not in fundamental
# 1554923 not in fundamental
# 1555082 not in fundamental
# 1579010 not in fundamental
# 1585644 not in fundamental
# 1588242 not in fundamental

# %%
print('Of', len(f_keys), 'bankrupt companies,', len(x), 'companies are not in fundamental dataset')
# Out:
# Of 2779 bankrupt companies, 1085 companies are not in fundamental dataset

# %%
# # gvkey_list = str(list(all_fund['GVKEY'].unique())).strip('\'').strip('[').strip(']').split(', ')

# # Write to txt file to look up relevant companies in Audit Analytics database
# file = open('all_fkey.txt','w')
# for i in all_bank['COMPANY_FKEY']:
#     file.write(str(i))
#     file.write('\n')
# file.close()

# %%
#used bankruptcy Fkey to query fundamental data, turns out a lot of ciks do not return fundamental data
fund_bank = pd.read_csv('fund_bank.csv')
fund_bank['cik'].nunique()
# Out:
# C:\Users\Joseph\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (23,33,955,956,958,959,965,976,977,980,981,982,983,985,989,995,996,999,1002,1005,1010,1017,1018,1021,1025,1030,1033,1034,1039,1049,1050,1055,1056,1057,1058,1059,1060,1061,1065,1066,1069,1070,1072,1074,1076,1077,1081,1082,1083,1093,1095,1099,1100,1107,1111,1112,1113,1114,1116,1120,1127,1134,1137,1141,1144,1145,1146,1148,1149,1150,1159,1160,1162,1163,1164,1165,1167,1168,1829,1830,1836,1850,1851) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 1798

# %%
print('will move forward with the companies with fundamental data')
print('might be benefitial to figure out why so many companies do not have fundamental data')
# Out:
# will move forward with the companies with fundamental data
# might be benefitial to figure out why so many companies do not have fundamental data

# %% [markdown]
# ## Merge fundamental and bankruptcy and financial ratios

# %%
fund_bank = pd.merge(all_fund, all_bank, left_on = 'cik', right_on = 'COMPANY_FKEY', suffixes = ('_fund', '_bank'), how = 'left')
fund_bank['cik'].nunique()
# Out:
# 17998

# %%
bankrupt_key  = pd.merge(all_bank, key_table, left_on = 'COMPANY_FKEY', right_on = 'cik', suffixes = ('_ratio', '_key'), how = 'inner')

# %%
all_fin_ratios  = pd.read_csv('all_fin_ratios.csv')

# %%
#only keep year end financial ratios for each company
all_fin_ratios=all_fin_ratios.drop_duplicates(subset=['gvkey','qdate'], keep='last')
all_fin_ratios['qmonth']=pd.to_datetime(all_fin_ratios['qdate']).dt.month
mask= all_fin_ratios['qmonth']==12
all_fin_ratios= all_fin_ratios[mask]

all_fin_ratios.shape
# Out:
# (75263, 76)

# %%
fin_gv = list(all_fin_ratios['gvkey'].unique())

fund_gv = list(all_fund['GVKEY'].unique())

#test how many bankrupt Fkeys are in fundamental
x = [] 
for i in fin_gv:
    
    if i in fund_gv:
        continue
    
    else:
        x.append(i)
        print (i, 'not in fundamental')
# Out:
# 1411 not in fundamental
# 1542 not in fundamental
# 3391 not in fundamental
# 4806 not in fundamental
# 5181 not in fundamental
# 6282 not in fundamental
# 7503 not in fundamental
# 7837 not in fundamental
# 8248 not in fundamental
# 11768 not in fundamental
# 13486 not in fundamental
# 14825 not in fundamental
# 17164 not in fundamental
# 17560 not in fundamental
# 18693 not in fundamental
# 18769 not in fundamental
# 18914 not in fundamental
# 22525 not in fundamental
# 23692 not in fundamental
# 24779 not in fundamental
# 25271 not in fundamental
# 29402 not in fundamental
# 29982 not in fundamental
# 30240 not in fundamental
# 30599 not in fundamental
# 30757 not in fundamental
# 30764 not in fundamental
# 31097 not in fundamental
# 61606 not in fundamental
# 62004 not in fundamental
# 62069 not in fundamental
# 62338 not in fundamental
# 62450 not in fundamental
# 62513 not in fundamental
# 63207 not in fundamental
# 64509 not in fundamental
# 64996 not in fundamental
# 65629 not in fundamental
# 65667 not in fundamental
# 65882 not in fundamental
# 65936 not in fundamental
# 65988 not in fundamental
# 111321 not in fundamental
# 111408 not in fundamental
# 111973 not in fundamental
# 113652 not in fundamental
# 120357 not in fundamental
# 122156 not in fundamental
# 122396 not in fundamental
# 124051 not in fundamental
# 4191 not in fundamental
# 7635 not in fundamental
# 9857 not in fundamental
# 10071 not in fundamental
# 11040 not in fundamental
# 11236 not in fundamental
# 12337 not in fundamental
# 12460 not in fundamental
# 13016 not in fundamental
# 15761 not in fundamental
# 16600 not in fundamental
# 23953 not in fundamental
# 24885 not in fundamental
# 28125 not in fundamental
# 28305 not in fundamental
# 28497 not in fundamental
# 28546 not in fundamental
# 30866 not in fundamental
# 30994 not in fundamental
# 61681 not in fundamental
# 61701 not in fundamental
# 62544 not in fundamental
# 62716 not in fundamental
# 63269 not in fundamental
# 63523 not in fundamental
# 63594 not in fundamental
# 64056 not in fundamental
# 64415 not in fundamental
# 65880 not in fundamental
# 66043 not in fundamental
# 107670 not in fundamental
# 120218 not in fundamental
# 120793 not in fundamental
# 1278 not in fundamental
# 1297 not in fundamental
# 1781 not in fundamental
# 1786 not in fundamental
# 1831 not in fundamental
# 1832 not in fundamental
# 1848 not in fundamental
# 2175 not in fundamental
# 2213 not in fundamental
# 2267 not in fundamental
# 2322 not in fundamental
# 2461 not in fundamental
# 2498 not in fundamental
# 2562 not in fundamental
# 2646 not in fundamental
# 2847 not in fundamental
# 2860 not in fundamental
# 2891 not in fundamental
# 2917 not in fundamental
# 3255 not in fundamental
# 3273 not in fundamental
# 3291 not in fundamental
# 3393 not in fundamental
# 3422 not in fundamental
# 3618 not in fundamental
# 3892 not in fundamental
# 3911 not in fundamental
# 3933 not in fundamental
# 4024 not in fundamental
# 4121 not in fundamental
# 4160 not in fundamental
# 4189 not in fundamental
# 4335 not in fundamental
# 4381 not in fundamental
# 4556 not in fundamental
# 4585 not in fundamental
# 4736 not in fundamental
# 4961 not in fundamental
# 4972 not in fundamental
# 5211 not in fundamental
# 5464 not in fundamental
# 5465 not in fundamental
# 5485 not in fundamental
# 5503 not in fundamental
# 5721 not in fundamental
# 6035 not in fundamental
# 6226 not in fundamental
# 6272 not in fundamental
# 6288 not in fundamental
# 6301 not in fundamental
# 6459 not in fundamental
# 6492 not in fundamental
# 6744 not in fundamental
# 6745 not in fundamental
# 6825 not in fundamental
# 7007 not in fundamental
# 7562 not in fundamental
# 7574 not in fundamental
# 7617 not in fundamental
# 7758 not in fundamental
# 7777 not in fundamental
# 8000 not in fundamental
# 8050 not in fundamental
# 8051 not in fundamental
# 8118 not in fundamental
# 8299 not in fundamental
# 8595 not in fundamental
# 8658 not in fundamental
# 8792 not in fundamental
# 8804 not in fundamental
# 8846 not in fundamental
# 8880 not in fundamental
# 8974 not in fundamental
# 9113 not in fundamental
# 9114 not in fundamental
# 9180 not in fundamental
# 9308 not in fundamental
# 9371 not in fundamental
# 9406 not in fundamental
# 9635 not in fundamental
# 9643 not in fundamental
# 9742 not in fundamental
# 9837 not in fundamental
# 10092 not in fundamental
# 10304 not in fundamental
# 10333 not in fundamental
# 10359 not in fundamental
# 10422 not in fundamental
# 10435 not in fundamental
# 10537 not in fundamental
# 10576 not in fundamental
# 10580 not in fundamental
# 10665 not in fundamental
# 10950 not in fundamental
# 10993 not in fundamental
# 11113 not in fundamental
# 11238 not in fundamental
# 11288 not in fundamental
# 11319 not in fundamental
# 11407 not in fundamental
# 11436 not in fundamental
# 11618 not in fundamental
# 11807 not in fundamental
# 11852 not in fundamental
# 11853 not in fundamental
# 11902 not in fundamental
# 11985 not in fundamental
# 12238 not in fundamental
# 12331 not in fundamental
# 12382 not in fundamental
# 12397 not in fundamental
# 12467 not in fundamental
# 12476 not in fundamental
# 12480 not in fundamental
# 12548 not in fundamental
# 12570 not in fundamental
# 12571 not in fundamental
# 12738 not in fundamental
# 13031 not in fundamental
# 13042 not in fundamental
# 13049 not in fundamental
# 13055 not in fundamental
# 13102 not in fundamental
# 13197 not in fundamental
# 13387 not in fundamental
# 13417 not in fundamental
# 13600 not in fundamental
# 14263 not in fundamental
# 14290 not in fundamental
# 14337 not in fundamental
# 14416 not in fundamental
# 14554 not in fundamental
# 14809 not in fundamental
# 15113 not in fundamental
# 15248 not in fundamental
# 15302 not in fundamental
# 16420 not in fundamental
# 16469 not in fundamental
# 16550 not in fundamental
# 16601 not in fundamental
# 16683 not in fundamental
# 16739 not in fundamental
# 16822 not in fundamental
# 16852 not in fundamental
# 16860 not in fundamental
# 16887 not in fundamental
# 16930 not in fundamental
# 16977 not in fundamental
# 17433 not in fundamental
# 17680 not in fundamental
# 17863 not in fundamental
# 18058 not in fundamental
# 18238 not in fundamental
# 19346 not in fundamental
# 19552 not in fundamental
# 19950 not in fundamental
# 20046 not in fundamental
# 20118 not in fundamental
# 20197 not in fundamental
# 21217 not in fundamental
# 21757 not in fundamental
# 22980 not in fundamental
# 23045 not in fundamental
# 23076 not in fundamental
# 23135 not in fundamental
# 23487 not in fundamental
# 23934 not in fundamental
# 24140 not in fundamental
# 24279 not in fundamental
# 24338 not in fundamental
# 24386 not in fundamental
# 24395 not in fundamental
# 24510 not in fundamental
# 24511 not in fundamental
# 24707 not in fundamental
# 24845 not in fundamental
# 24908 not in fundamental
# 24920 not in fundamental
# 24988 not in fundamental
# 25004 not in fundamental
# 25076 not in fundamental
# 25114 not in fundamental
# 25149 not in fundamental
# 25225 not in fundamental
# 25240 not in fundamental
# 25281 not in fundamental
# 25401 not in fundamental
# 25441 not in fundamental
# 25650 not in fundamental
# 25688 not in fundamental
# 25806 not in fundamental
# 25828 not in fundamental
# 25864 not in fundamental
# 26009 not in fundamental
# 26023 not in fundamental
# 26034 not in fundamental
# 27793 not in fundamental
# 28109 not in fundamental
# 28120 not in fundamental
# 28138 not in fundamental
# 28147 not in fundamental
# 28229 not in fundamental
# 28250 not in fundamental
# 28258 not in fundamental
# 28319 not in fundamental
# 28364 not in fundamental
# 28489 not in fundamental
# 28579 not in fundamental
# 28618 not in fundamental
# 28707 not in fundamental
# 28732 not in fundamental
# 28756 not in fundamental
# 28781 not in fundamental
# 28828 not in fundamental
# 28848 not in fundamental
# 28904 not in fundamental
# 28953 not in fundamental
# 28973 not in fundamental
# 28981 not in fundamental
# 29174 not in fundamental
# 29266 not in fundamental
# 29396 not in fundamental
# 29547 not in fundamental
# 29643 not in fundamental
# 29878 not in fundamental
# 29963 not in fundamental
# 29988 not in fundamental
# 30027 not in fundamental
# 30070 not in fundamental
# 30088 not in fundamental
# 30131 not in fundamental
# 30191 not in fundamental
# 30254 not in fundamental
# 30325 not in fundamental
# 30400 not in fundamental
# 30595 not in fundamental
# 30623 not in fundamental
# 30639 not in fundamental
# 30703 not in fundamental
# 30738 not in fundamental
# 30750 not in fundamental
# 30759 not in fundamental
# 30782 not in fundamental
# 30836 not in fundamental
# 30849 not in fundamental
# 31007 not in fundamental
# 31100 not in fundamental
# 31135 not in fundamental
# 31204 not in fundamental
# 31291 not in fundamental
# 31427 not in fundamental
# 31454 not in fundamental
# 31504 not in fundamental
# 31551 not in fundamental
# 31571 not in fundamental
# 31620 not in fundamental
# 31663 not in fundamental
# 31679 not in fundamental
# 31693 not in fundamental
# 31697 not in fundamental
# 31700 not in fundamental
# 31757 not in fundamental
# 60825 not in fundamental
# 60933 not in fundamental
# 60936 not in fundamental
# 60975 not in fundamental
# 61046 not in fundamental
# 61086 not in fundamental
# 61088 not in fundamental
# 61093 not in fundamental
# 61094 not in fundamental
# 61175 not in fundamental
# 61247 not in fundamental
# 61326 not in fundamental
# 61370 not in fundamental
# 61372 not in fundamental
# 61413 not in fundamental
# 61464 not in fundamental
# 61507 not in fundamental
# 61508 not in fundamental
# 61553 not in fundamental
# 61590 not in fundamental
# 61601 not in fundamental
# 61700 not in fundamental
# 61705 not in fundamental
# 61780 not in fundamental
# 61873 not in fundamental
# 61999 not in fundamental
# 62137 not in fundamental
# 62284 not in fundamental
# 62314 not in fundamental
# 62320 not in fundamental
# 62356 not in fundamental
# 62368 not in fundamental
# 62377 not in fundamental
# 62433 not in fundamental
# 62519 not in fundamental
# 62535 not in fundamental
# 62659 not in fundamental
# 62690 not in fundamental
# 62697 not in fundamental
# 62707 not in fundamental
# 62737 not in fundamental
# 62759 not in fundamental
# 62932 not in fundamental
# 63013 not in fundamental
# 63140 not in fundamental
# 63182 not in fundamental
# 63199 not in fundamental
# 63200 not in fundamental
# 63201 not in fundamental
# 63225 not in fundamental
# 63278 not in fundamental
# 63296 not in fundamental
# 63478 not in fundamental
# 63509 not in fundamental
# 63641 not in fundamental
# 63693 not in fundamental
# 63744 not in fundamental
# 63770 not in fundamental
# 63775 not in fundamental
# 63779 not in fundamental
# 63791 not in fundamental
# 63797 not in fundamental
# 63832 not in fundamental
# 63877 not in fundamental
# 63886 not in fundamental
# 63918 not in fundamental
# 63920 not in fundamental
# 64168 not in fundamental
# 64174 not in fundamental
# 64198 not in fundamental
# 64200 not in fundamental
# 64299 not in fundamental
# 64307 not in fundamental
# 64345 not in fundamental
# 64369 not in fundamental
# 64398 not in fundamental
# 64537 not in fundamental
# 64611 not in fundamental
# 64631 not in fundamental
# 64669 not in fundamental
# 64687 not in fundamental
# 64711 not in fundamental
# 64769 not in fundamental
# 64776 not in fundamental
# 64813 not in fundamental
# 64880 not in fundamental
# 64886 not in fundamental
# 64898 not in fundamental
# 64899 not in fundamental
# 64936 not in fundamental
# 64956 not in fundamental
# 64961 not in fundamental
# 64967 not in fundamental
# 64983 not in fundamental
# 64989 not in fundamental
# 65020 not in fundamental
# 65028 not in fundamental
# 65149 not in fundamental
# 65184 not in fundamental
# 65282 not in fundamental
# 65420 not in fundamental
# 65477 not in fundamental
# 65488 not in fundamental
# 65593 not in fundamental
# 65604 not in fundamental
# 65653 not in fundamental
# 65705 not in fundamental
# 65716 not in fundamental
# 65724 not in fundamental
# 65731 not in fundamental
# 65748 not in fundamental
# 65749 not in fundamental
# 65777 not in fundamental
# 65785 not in fundamental
# 65852 not in fundamental
# 65870 not in fundamental
# 65913 not in fundamental
# 65945 not in fundamental
# 66003 not in fundamental
# 66101 not in fundamental
# 66293 not in fundamental
# 66418 not in fundamental
# 66423 not in fundamental
# 66477 not in fundamental
# 66563 not in fundamental
# 66625 not in fundamental
# 66634 not in fundamental
# 66656 not in fundamental
# 66658 not in fundamental
# 66716 not in fundamental
# 105943 not in fundamental
# 106820 not in fundamental
# 106847 not in fundamental
# 107830 not in fundamental
# 107895 not in fundamental
# 109185 not in fundamental
# 109762 not in fundamental
# 110535 not in fundamental
# 110536 not in fundamental
# 110575 not in fundamental
# 110624 not in fundamental
# 110759 not in fundamental
# 111869 not in fundamental
# 111875 not in fundamental
# 113370 not in fundamental
# 113489 not in fundamental
# 113832 not in fundamental
# 114957 not in fundamental
# 116431 not in fundamental
# 116505 not in fundamental
# 116609 not in fundamental
# 116827 not in fundamental
# 118322 not in fundamental
# 118579 not in fundamental
# 118653 not in fundamental
# 119016 not in fundamental
# 119214 not in fundamental
# 119256 not in fundamental
# 119536 not in fundamental
# 119773 not in fundamental
# 120215 not in fundamental
# 120278 not in fundamental
# 120435 not in fundamental
# 120655 not in fundamental
# 120714 not in fundamental
# 120716 not in fundamental
# 120720 not in fundamental
# 120825 not in fundamental
# 121293 not in fundamental
# 121374 not in fundamental
# 121383 not in fundamental
# 121453 not in fundamental
# 121561 not in fundamental
# 121615 not in fundamental
# 121742 not in fundamental
# 121761 not in fundamental
# 122149 not in fundamental
# 122354 not in fundamental
# 122378 not in fundamental
# 122517 not in fundamental
# 122742 not in fundamental
# 122835 not in fundamental
# 122837 not in fundamental
# 122894 not in fundamental
# 122919 not in fundamental
# 123134 not in fundamental
# 124015 not in fundamental
# 124035 not in fundamental
# 124177 not in fundamental
# 124377 not in fundamental
# 124679 not in fundamental
# 124681 not in fundamental
# 125598 not in fundamental
# 126005 not in fundamental
# 126414 not in fundamental
# 126420 not in fundamental
# 126459 not in fundamental
# 126616 not in fundamental
# 127175 not in fundamental
# 127275 not in fundamental
# 127382 not in fundamental
# 127399 not in fundamental
# 127414 not in fundamental
# 127486 not in fundamental
# 129083 not in fundamental
# 130303 not in fundamental
# 153351 not in fundamental
# 10978 not in fundamental
# 23622 not in fundamental
# 29357 not in fundamental
# 31152 not in fundamental
# 3078 not in fundamental
# 30031 not in fundamental
# 6285 not in fundamental
# 189546 not in fundamental

# %%
print('Of', len(fin_gv), 'companies with financial ratios', len(x), 'companies are not in fundamental dataset')
# Out:
# Of 9466 companies with financial ratios 560 companies are not in fundamental dataset

# %%
fin_ratio_bankruptcy = pd.merge(all_fin_ratios, bankrupt_key, left_on = 'gvkey', right_on = 'GVKEY', suffixes = ('_finratio', '_bankrupt'), how = 'left')

# %%
mask = pd.to_datetime(fin_ratio_bankruptcy['adate']).dt.year + 1 == pd.to_datetime(fin_ratio_bankruptcy['BANK_BEGIN_DATE']).dt.year

fin_ratio_bankruptcy['bankrupted'] = np.where(mask, 1,0)

# %%
#might want to check why so few bankruptcies exist in this final merge dataset
fin_ratio_bankruptcy['bankrupted'].sum()
# Out:
# 518

# %%
fin_ratio_bankruptcy['year'] = pd.to_datetime(fin_ratio_bankruptcy['adate']).dt.year
all_fund['year'] =  pd.to_datetime(all_fund['datadate']).dt.year

# %%
fund_ratio_bank  = pd.merge(all_fund, fin_ratio_bankruptcy, left_on = ['GVKEY', 'year'], right_on = ['gvkey', 'year'], suffixes = ('_fund', '_ratio'), how = 'inner')
fund_ratio_bank = fund_ratio_bank.drop(columns = 'GVKEY_ratio')
fund_ratio_bank = fund_ratio_bank.rename(columns = {'GVKEY_fund' : 'GVKEY'})

# %%
print('The final dataset includes:',fund_ratio_bank['GVKEY'].nunique(), 'companies, which have fundamental as well as financial ratios values, and', fund_ratio_bank['bankrupted'].sum(), 'bankruptcies')
# Out:
# The final dataset includes: 8673 companies, which have fundamental as well as financial ratios values, and 511 bankruptcies

# %% [markdown]
# ## Final EDA

# %%
#filter for market cap size (in MM)
#recommend using this after creating bankruptcy dummy

def market_cap_size(df, lower, upper):
    
    mask = ((df['mkvalt'] >=lower) & (df['mkvalt'] <=upper))
    df =df[mask]
    
    return df


# #market cap 500M - 1B
# df500 = market_cap_size(fund_ratio_bank, 0,1000)

# df500['GVKEY'].nunique()

# %%
fund_ratio_bank.groupby('year')[['bankrupted']].sum().plot(kind = 'bar', figsize = (15,6))

# %%
final_bank = fund_ratio_bank [fund_ratio_bank['bankrupted']==1]

# %%
final_bank['SIC_CODE_DESCRIP'].value_counts(ascending = False)[:20].plot(kind = 'bar', figsize = (15,8))

# %%
#bankrupt companies usually have small market caps
final_bank['mkvalt'].plot(kind = 'hist', bins = 200)#.value_counts(ascending = False)[:20].plot(kind = 'bar', figsize = (15,8))
print('most bankrptcies happened with companies with small market caps')
# Out:
# most bankrptcies happened with companies with small market caps

# %% [markdown]
# ## Next steps:
# 1. figure out why so many bankrupted companies do not have fundamental data (is it how the database was constructed? fundamental dataset would get rid of bankrupted or acquired companies?)
#
# 2. figure out why only 500 or so bankruptcies exist in the final dataset, down from 1000 (bankrupt companies with fundamental data) --> hypothesis is some fin ratios companies do not have fundamental data and those happen to be the ones with bankrupt data. Need to check
#
# 3. model development. Note that the current dataset includes data from 2000 - 2019. Need to filter out dates

# %% [markdown]
# # Modeling

# %%
mask = (fund_ratio_bank['fyear'] >= 2000) & (fund_ratio_bank['fyear'] <= 2010)

df_2000_2010 = fund_ratio_bank[mask]

# %%
mask = (fund_ratio_bank['fyear'] == 2011)

df_2011 = fund_ratio_bank[mask]

# %%
lista=[]
for i in all_fin_ratios.columns:
    lista.append(i)

# %%
lista.append('bankrupted')
lista.append('fyear')

# %%
df_2000_2010 = df_2000_2010[lista]
df_2011 = df_2011[lista]

# %%
df_2000_2010 = df_2000_2010.drop(columns = ['gvkey'])
df_2011 = df_2011.drop(columns = ['gvkey'])

# %%
mask = (df_2000_2010['fyear'] >= 2000) & (df_2000_2010['fyear'] <= 2007)
train=df_2000_2010[mask]
test= df_2000_2010[-mask]

# %%
y_train= train['bankrupted']
x_train= train.drop(columns=['bankrupted'])
y_test= test['bankrupted']
x_test= test.drop(columns=['bankrupted'])

# %%
x_train=x_train.drop(columns=['adate','qdate','fyear','public_date','qmonth'])
x_test=x_test.drop(columns=['adate','qdate','fyear','public_date','qmonth'])

# %%
def get_pct(column):
    
    column = float(str(column).rstrip('%')) 
    
    return column

x_train['DIVYIELD'] = x_train['DIVYIELD'].apply(get_pct)
x_test['DIVYIELD'] = x_test['DIVYIELD'].apply(get_pct)

# %% [markdown]
# # SGD Classifier
# imputation: https://towardsdatascience.com/6-different-ways-to-compensate-for-missing-values-data-imputation-with-examples-6022d9ca0779

# %%
from sklearn.linear_model import SGDClassifier

clf = SGDClassifier(loss="log", max_iter=5).fit(x_train, y_train)
clf.predict_proba(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-146-744ecbb2bcc4> in <module>
#       1 from sklearn.linear_model import SGDClassifier
#       2
# ----> 3 clf = SGDClassifier(loss="log", max_iter=5).fit(x_train, y_train)
#       4 clf.predict_proba(x_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py in fit(self, X, y, coef_init, intercept_init, sample_weight)
#     711                          loss=self.loss, learning_rate=self.learning_rate,
#     712                          coef_init=coef_init, intercept_init=intercept_init,
# --> 713                          sample_weight=sample_weight)
#     714
#     715
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py in _fit(self, X, y, alpha, C, loss, learning_rate, coef_init, intercept_init, sample_weight)
#     527
#     528         X, y = check_X_y(X, y, 'csr', dtype=np.float64, order="C",
# --> 529                          accept_large_sparse=False)
#     530
#     531         # labels can be encoded as float, int, or string literals
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     717                     ensure_min_features=ensure_min_features,
#     718                     warn_on_dtype=warn_on_dtype,
# --> 719                     estimator=estimator)
#     720     if multi_output:
#     721         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     540         if force_all_finite:
#     541             _assert_all_finite(array,
# --> 542                                allow_nan=force_all_finite == 'allow-nan')
#     543
#     544     if ensure_min_samples > 0:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57     # for object dtype data, we only check for NaNs (GH-13254)
#      58     elif X.dtype == np.dtype('object') and not allow_nan:
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
x_train
# Out:
#          CAPEI     bm     evm  pe_op_basic  pe_op_dil  pe_exi  pe_inc      ps  \
# 1       28.326  0.497  12.016       12.852     13.385  15.181  15.181   0.771
# 2       34.133  0.846  13.648       36.383     36.383 -19.655 -18.387   0.689
# 3     -293.430  1.698   8.056       19.031     19.031  -9.920  -9.325   0.598
# 4     -253.970  1.106  12.002       29.365     29.767  57.184  80.481   0.678
# 5       -5.239  1.026  10.382       28.606     28.606  -1.560  -1.560   0.289
# ...        ...    ...     ...          ...        ...     ...     ...     ...
# 72267      NaN  0.590  21.864       13.700     14.172  14.172  14.172   3.980
# 72268      NaN  0.590  21.864       13.700     14.172  14.172  14.172   3.980
# 72288      NaN  0.703 -14.979      -18.556    -18.556 -16.700 -16.700  60.120
# 72321  -27.679  0.175  -8.041      -15.238    -15.238 -19.394 -19.394  56.916
# 72322  -16.085  0.140  -9.382       -7.271     -7.271  -7.271  -7.271   8.022
#
#           pcf    dpr  ...  sale_nwc  rd_sale  adv_sale  staff_sale  accrual  \
# 1      20.975  0.118  ...     2.286    0.048     0.000         0.0   -0.016
# 2       5.628    NaN  ...     3.053    0.089     0.000         0.0    0.078
# 3       4.541    NaN  ...     4.203    0.055     0.000         0.0    0.109
# 4       5.603  0.479  ...     3.876    0.049     0.000         0.0    0.059
# 5       2.077    NaN  ...       NaN    0.061     0.000         0.0    0.231
# ...       ...    ...  ...       ...      ...       ...         ...      ...
# 72267  11.119  0.000  ...     0.300    0.000     0.000         0.0    0.016
# 72268  11.119  0.000  ...     0.300    0.000     0.000         0.0    0.016
# 72288  -4.514    NaN  ...     0.050    0.000     0.000         0.0    0.068
# 72321 -18.434    NaN  ...     0.143    0.818     0.001         0.0   -0.016
# 72322  -6.969    NaN  ...     0.658    0.126     0.000         0.0   -0.066
#
#           ptb  PEG_trailing  DIVYIELD  PEG_1yrforward  PEG_ltgforward
# 1       0.792         0.596     0.796           0.642           0.678
# 2       0.677           NaN     1.050          -0.332          -0.874
# 3       0.708           NaN     0.965          -0.424          -0.601
# 4       0.761           NaN     0.828          -8.196           3.590
# 5       0.421           NaN     1.910          -0.065          -0.114
# ...       ...           ...       ...             ...             ...
# 72267   1.018           NaN       NaN           0.411           0.489
# 72268   1.018           NaN       NaN           0.411           0.489
# 72288   2.398           NaN       NaN             NaN             NaN
# 72321  11.848           NaN       NaN             NaN             NaN
# 72322   6.403           NaN       NaN             NaN             NaN
#
# [37103 rows x 71 columns]

# %%
#only keep na < 10% columns
temp = pd.DataFrame(1 - x_train.isna().sum() / 37103).reset_index()
use_list = temp[temp[0]>0.9]['index'].to_list()

# %%
x_train = x_train[use_list]

# %%
# start the MICE training
imputed_training=mice(x_train.values)

# %%
x_train
# Out:
#          CAPEI     bm     evm  pe_op_basic  pe_op_dil  pe_exi  pe_inc      ps  \
# 1       28.326  0.497  12.016       12.852     13.385  15.181  15.181   0.771
# 2       34.133  0.846  13.648       36.383     36.383 -19.655 -18.387   0.689
# 3     -293.430  1.698   8.056       19.031     19.031  -9.920  -9.325   0.598
# 4     -253.970  1.106  12.002       29.365     29.767  57.184  80.481   0.678
# 5       -5.239  1.026  10.382       28.606     28.606  -1.560  -1.560   0.289
# ...        ...    ...     ...          ...        ...     ...     ...     ...
# 72267      NaN  0.590  21.864       13.700     14.172  14.172  14.172   3.980
# 72268      NaN  0.590  21.864       13.700     14.172  14.172  14.172   3.980
# 72288      NaN  0.703 -14.979      -18.556    -18.556 -16.700 -16.700  60.120
# 72321  -27.679  0.175  -8.041      -15.238    -15.238 -19.394 -19.394  56.916
# 72322  -16.085  0.140  -9.382       -7.271     -7.271  -7.271  -7.271   8.022
#
#           pcf    dpr  ...  sale_nwc  rd_sale  adv_sale  staff_sale  accrual  \
# 1      20.975  0.118  ...     2.286    0.048     0.000         0.0   -0.016
# 2       5.628    NaN  ...     3.053    0.089     0.000         0.0    0.078
# 3       4.541    NaN  ...     4.203    0.055     0.000         0.0    0.109
# 4       5.603  0.479  ...     3.876    0.049     0.000         0.0    0.059
# 5       2.077    NaN  ...       NaN    0.061     0.000         0.0    0.231
# ...       ...    ...  ...       ...      ...       ...         ...      ...
# 72267  11.119  0.000  ...     0.300    0.000     0.000         0.0    0.016
# 72268  11.119  0.000  ...     0.300    0.000     0.000         0.0    0.016
# 72288  -4.514    NaN  ...     0.050    0.000     0.000         0.0    0.068
# 72321 -18.434    NaN  ...     0.143    0.818     0.001         0.0   -0.016
# 72322  -6.969    NaN  ...     0.658    0.126     0.000         0.0   -0.066
#
#           ptb  PEG_trailing  DIVYIELD  PEG_1yrforward  PEG_ltgforward
# 1       0.792         0.596     0.796           0.642           0.678
# 2       0.677           NaN     1.050          -0.332          -0.874
# 3       0.708           NaN     0.965          -0.424          -0.601
# 4       0.761           NaN     0.828          -8.196           3.590
# 5       0.421           NaN     1.910          -0.065          -0.114
# ...       ...           ...       ...             ...             ...
# 72267   1.018           NaN       NaN           0.411           0.489
# 72268   1.018           NaN       NaN           0.411           0.489
# 72288   2.398           NaN       NaN             NaN             NaN
# 72321  11.848           NaN       NaN             NaN             NaN
# 72322   6.403           NaN       NaN             NaN             NaN
#
# [37103 rows x 71 columns]
