# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Fundamental data preprocessing

# %%
# CSV of publically traded healthcare companies as classified by GIC subindustry codes
df = pd.read_csv('healthcare_fundamentals_v3.csv') #update w/ latest version

key_table = df[['cik', 'GVKEY']] #keys to join all databases
key_table.head()
# Out:
# C:\Users\Hannah\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (23,33,37,955,956,957,962,976,977) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         cik  GVKEY
# 0  319126.0   1021
# 1  319126.0   1021
# 2  319126.0   1021
# 3  319126.0   1021
# 4  319126.0   1021

# %%
df['seq']
# Out:
# 0        4.455
# 1        2.717
# 2        2.823
# 3        1.320
# 4        2.665
#          ...
# 14060      NaN
# 14061      NaN
# 14062   -7.074
# 14063      NaN
# 14064   -1.594
# Name: seq, Length: 14065, dtype: float64

# %%
df['mkvalt']
# Out:
# 0         4.5428
# 1         2.9667
# 2         1.5761
# 3         1.5761
# 4        13.9065
#           ...
# 14060        NaN
# 14061        NaN
# 14062        NaN
# 14063        NaN
# 14064        NaN
# Name: mkvalt, Length: 14065, dtype: float64

# %%
#all companies in healthcare industry from 2000 - 2010
print('Total number of unique companies from 2000 - 2010:',df['GVKEY'].nunique())
# Out:
# Total number of unique companies from 2000 - 2010: 1975

# %%
#eliminate private companies (ipodate = nan)
mask = df['ipodate'].isna()
print(mask.sum())
print(df.shape)
print(df[-mask].shape)
df = df[-mask]
# Out:
# 5251
# (14065, 988)
# (8814, 988)

# %%
#number of public healthcare companies
print('Total number of unique public companies from 2000 - 2010:',df['GVKEY'].nunique())
# Out:
# Total number of unique public companies from 2000 - 2010: 1175

# %%
#eliminate rows with no market cap information
mask = df['mkvalt'].isna()
df = df[-mask]
print('Total number of unique public companies with market cap from 2000 - 2010:',df['GVKEY'].nunique())
# Out:
# Total number of unique public companies with market cap from 2000 - 2010: 1055

# %%
# df['year'] =  pd.to_datetime(df['datadate']).dt.year
# mask = df['year'] == 2000

# df[mask]['GVKEY'].value_counts()

# %%
df['year'] =  pd.to_datetime(df['datadate']).dt.year
df = df.drop_duplicates(['year','GVKEY'])

# %%
print('Total number of unique private companies with market cap from 2000 - 2010:',df['GVKEY'].nunique())
# Out:
# Total number of unique private companies with market cap from 2000 - 2010: 1055

# %% [markdown]
# # Read in Bankruptcy Data and Merge with Fundamentals

# %%
# Bankrupt healthcare companies
df_bankrupt = pd.read_csv('healthcare_bankrupt_audit_analytics_v2.csv')

# %%
print('Total of:' ,len(df_bankrupt), "bankruptcy filings")
# Out:
# Total of: 187 bankruptcy filings

# %%
#create year column
df_bankrupt['bankrupt_year'] = pd.to_datetime(df_bankrupt['BANK_BEGIN_DATE']).dt.year

#filter for year 2001- 2010
mask = (df_bankrupt['bankrupt_year'] >2000) &  (df_bankrupt['bankrupt_year']  < 2011)
df_bankrupt = df_bankrupt[mask]

# %%
print('Total of:' ,len(df_bankrupt), "bankruptcy filings between 2001 and 2010")
# Out:
# Total of: 129 bankruptcy filings between 2001 and 2010

# %%
# Get chapter 11 companies only
df_bankrupt= df_bankrupt[df_bankrupt['BANKRUPTCY_TYPE']==11]
print('Total of:' ,len(df_bankrupt), "CH 11 bankruptcy filings between 2001 and 2010")
# Out:
# Total of: 82 CH 11 bankruptcy filings between 2001 and 2010

# %%
df_bankrupt['bankrupt_year'].value_counts().sort_index().plot(kind = 'bar', title = 'Number of CH11 Bankruptcies by Year')

# %% [markdown]
# # Merge Financial Ratios

# %%
#create cik - GVKEY table from fundamentals dataset
key_table = key_table.drop_duplicates()
key_table.head()
# Out:
#          cik  GVKEY
# 0   319126.0   1021
# 9   730469.0   1034
# 17    1800.0   1078
# 28    2034.0   1094
# 39  313798.0   1115

# %%
df_fin_ratio = pd.read_csv('fin ratios.csv')
df_fin_ratio['gvkey'].nunique()
# Out:
# 1244

# %%
bankrupt_key  = pd.merge(df_bankrupt, key_table, left_on = 'COMPANY_FKEY', right_on = 'cik', suffixes = ('_ratio', '_key'), how = 'inner')
# df_table = df_table.drop_duplicates()

# %%
bankrupt_key.shape
# Out:
# (82, 467)

# %%
df_fin_ratio=df_fin_ratio.drop_duplicates(subset=['gvkey','qdate'], keep='last')
df_fin_ratio['qmonth']=pd.to_datetime(df_fin_ratio['qdate']).dt.month
mask= df_fin_ratio['qmonth']==12
df_fin_ratio= df_fin_ratio[mask]

df_fin_ratio.shape
# Out:
# (7526, 76)

# %%
fin_ratio_bankruptcy = pd.merge(df_fin_ratio, bankrupt_key, left_on = 'gvkey', right_on = 'GVKEY', suffixes = ('_finratio', '_bankrupt'), how = 'left')
#processing for fin ratio to drop duplicates
fin_ratio_bankruptcy['year'] = pd.to_datetime(fin_ratio_bankruptcy['adate']).dt.year

# %%
fin_ratio_bankruptcy.shape
# Out:
# (7526, 544)

# %%
#create bankruptcy dummy
#adate is year end date
mask = pd.to_datetime(fin_ratio_bankruptcy['adate']).dt.year + 1 == pd.to_datetime(fin_ratio_bankruptcy['BANK_BEGIN_DATE']).dt.year

fin_ratio_bankruptcy['bankrupted'] = np.where(mask, 1,0)

# %%
fin_ratio_bankruptcy['gvkey'].nunique()
# Out:
# 1154

# %%
fin_ratio_bankruptcy['year'] = pd.to_datetime(fin_ratio_bankruptcy['adate']).dt.year

# %%
fund_ratio_bank  = pd.merge(df, fin_ratio_bankruptcy, left_on = ['GVKEY', 'year'], right_on = ['gvkey', 'year'], suffixes = ('_fund', '_ratio'), how = 'inner')
fund_ratio_bank = fund_ratio_bank.drop(columns = 'GVKEY_ratio')
fund_ratio_bank = fund_ratio_bank.rename(columns = {'GVKEY_fund' : 'GVKEY'})

# %%
print('The final dataset includes:',fund_ratio_bank['GVKEY'].nunique(), 'companies, which have fundamental as well as financial ratios values')
# Out:
# The final dataset includes: 817 companies, which have fundamental as well as financial ratios values

# %%
fund_ratio_bank.head()
# Out:
#    GVKEY LINKPRIM LIID LINKTYPE  LPERMNO  LPERMCO      LINKDT   LINKENDDT  \
# 0   1177        P   01       LC  88845.0  41072.0  12/14/2000  11/30/2018
# 1   1177        P   01       LC  88845.0  41072.0  12/14/2000  11/30/2018
# 2   1177        J   03       NR      NaN      NaN  06/29/2001  01/31/2006
# 3   1177        P   01       LC  88845.0  41072.0  12/14/2000  11/30/2018
# 4   1177        P   01       LC  88845.0  41072.0  12/14/2000  11/30/2018
#
#      datadate   fyear  ... HIWATER_INCMST_NETINC_TTM_DATE  \
# 0  12/31/2000  2000.0  ...                            NaN
# 1  12/31/2001  2001.0  ...                            NaN
# 2  12/31/2002  2002.0  ...                            NaN
# 3  12/31/2003  2003.0  ...                            NaN
# 4  12/31/2004  2004.0  ...                            NaN
#
#   HIWATER_INCMST_NETINC_TTM HIWATER_INCMST_NETINC_FY_DATE  \
# 0                       NaN                           NaN
# 1                       NaN                           NaN
# 2                       NaN                           NaN
# 3                       NaN                           NaN
# 4                       NaN                           NaN
#
#   HIWATER_INCMST_NETINC_FY NAME_CHANGE_DATE1 NAME_CHANGE_DATE2  \
# 0                      NaN               NaN               NaN
# 1                      NaN               NaN               NaN
# 2                      NaN               NaN               NaN
# 3                      NaN               NaN               NaN
# 4                      NaN               NaN               NaN
#
#   NAME_CHANGE_DATE3 bankrupt_year cik_ratio bankrupted
# 0               NaN           NaN       NaN          0
# 1               NaN           NaN       NaN          0
# 2               NaN           NaN       NaN          0
# 3               NaN           NaN       NaN          0
# 4               NaN           NaN       NaN          0
#
# [5 rows x 1532 columns]

# %%
#filter for market cap size (in MM)
#recommend using this after creating bankruptcy dummy

def market_cap_size(df, lower, upper):
    
    mask = ((df['mkvalt'] >=lower) & (df['mkvalt'] <=upper))
    df =df[mask]
    
    return df


#market cap 500M - 1B
df500 = market_cap_size(fund_ratio_bank, 0,1000)

df500['GVKEY'].nunique()
# Out:
# 747

# %%
df500['bankrupted'].sum()
# Out:
# 24

# %%
df500.groupby('year')[['bankrupted']].sum()#.plot(kind = 'bar', figsize = (10,5), title = 'Number of Bankruptcies by Year, Companies with Market Cap Less than 1B', color = 'teal')
# Out:
#       bankrupted
# year
# 2000           2
# 2001           5
# 2002           4
# 2003           1
# 2004           2
# 2005           2
# 2006           0
# 2007           4
# 2008           2
# 2009           2

# %%
df500.groupby('year')[['GVKEY']].count()#.plot(kind = 'bar', figsize = (10,5), title = 'Number of Bankruptcies by Year, Companies with Market Cap Less than 1B', color = 'teal')
# Out:
#       GVKEY
# year
# 2000    480
# 2001    459
# 2002    441
# 2003    399
# 2004    405
# 2005    395
# 2006    387
# 2007    371
# 2008    364
# 2009    327

# %%
pd.DataFrame(df500.groupby('year')[['bankrupted']].sum()['bankrupted'] / df500.groupby('year')[['GVKEY']].count()['GVKEY']*100) .plot(kind = 'bar', color = 'teal', legend = False, title = '% Bankrupted Companies by Year', figsize = (10,6))

# %%
# get list of financial ratio that could be used as input
listratio=[]
for col in df_fin_ratio.columns: 
    listratio.append(col)

# %%
#for i in listratio:
    #print(i,"NULL:",df500[i].isnull().sum())

# %%
df500['curr_debt']
# Out:
# 21      0.348
# 22      0.314
# 23      0.403
# 24      0.432
# 25      0.435
#         ...
# 4899    0.345
# 4900    0.716
# 4901    0.857
# 4902    0.814
# 4903    1.000
# Name: curr_debt, Length: 4028, dtype: float64

# %%
df500['bankrupted'].sum()
# Out:
# 24

# %%
#de_ratio, debt_ebitda, roa, cash_debt, quick_ratio, intcov_ratio

# %%
df_dataset= df500[['de_ratio', 'debt_ebitda', 'roa', 'cash_debt', 'quick_ratio', 'intcov_ratio','bankrupted','adate']]

# %%
df_dataset=df_dataset.dropna()

# %%
df_dataset['bankrupted'].sum()
# Out:
# 24

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score, f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression, LinearRegression, Lasso
from sklearn.model_selection import GridSearchCV

import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from pandas import Series, DataFrame
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score,recall_score
from sklearn.metrics import auc
from sklearn.metrics import mean_squared_error
import seaborn as sns

#presentation: start w/ abstract

# %%
df_dataset
# Out:
#       de_ratio  debt_ebitda    roa  cash_debt  quick_ratio  intcov_ratio  \
# 21       0.338        1.333  0.079      0.309        8.660        87.403
# 24       0.550        0.565  0.079      0.168        1.420        20.741
# 34       0.052       -0.024 -0.910     -9.887       19.707     -4897.000
# 39       3.645       -0.664 -0.548     -0.646        2.442       -51.844
# 40      -6.914       -1.817 -0.474     -0.327        3.291        -7.686
# ...        ...          ...    ...        ...          ...           ...
# 4899     1.558       -0.055 -0.592     -1.178        4.020      -123.510
# 4900     0.521       -0.112 -0.305     -0.475        3.875       -75.458
# 4901     0.347       -0.111 -0.349     -1.844        4.158       -82.089
# 4902     0.263       -0.085 -0.387     -3.509        5.264       -70.815
# 4903     0.098        0.000 -0.362     -4.238        9.165       -25.062
#
#       bankrupted       adate
# 21             0  12/31/2000
# 24             0  12/31/2003
# 34             0  09/30/2000
# 39             0  12/31/2005
# 40             0  12/31/2006
# ...          ...         ...
# 4899           0  12/31/2006
# 4900           0  12/31/2007
# 4901           0  12/31/2008
# 4902           0  12/31/2009
# 4903           0  12/31/2009
#
# [2856 rows x 8 columns]

# %%
mask_test = pd.to_datetime(df_dataset['adate']).dt.year >=2007
train=df_dataset[~mask_test]
test=df_dataset[mask_test]

# %%
test
# Out:
#       de_ratio  debt_ebitda    roa  cash_debt  quick_ratio  intcov_ratio  \
# 41       0.274       -0.068 -0.461     -1.142        2.639       -19.547
# 42       0.201       -0.020 -0.366      0.576        5.801       -81.324
# 43       0.475       -0.017 -0.878     -0.195        3.764      -179.030
# 50     -10.548       -8.984 -0.102     -0.114        1.977        -1.347
# 51      -3.144       -9.783 -0.090     -0.122        0.135        -0.959
# ...        ...          ...    ...        ...          ...           ...
# 4888     0.258       -0.085 -0.474     -2.277        6.248      -112.570
# 4900     0.521       -0.112 -0.305     -0.475        3.875       -75.458
# 4901     0.347       -0.111 -0.349     -1.844        4.158       -82.089
# 4902     0.263       -0.085 -0.387     -3.509        5.264       -70.815
# 4903     0.098        0.000 -0.362     -4.238        9.165       -25.062
#
#       bankrupted       adate
# 41             0  12/31/2007
# 42             0  12/31/2008
# 43             0  12/31/2009
# 50             0  12/31/2007
# 51             1  12/31/2008
# ...          ...         ...
# 4888           0  12/31/2009
# 4900           0  12/31/2007
# 4901           0  12/31/2008
# 4902           0  12/31/2009
# 4903           0  12/31/2009
#
# [754 rows x 8 columns]

# %%
train= train.drop(columns='adate')
test= test.drop(columns='adate')

# %%
y_train= train['bankrupted']
train= train.drop(columns=['bankrupted'])

# %%
x_train= train

# %% [markdown]
# ## Random  Forest

# %%
#random forest
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
clf = RandomForestClassifier(max_depth=2, random_state=0, class_weight='balanced')

rgr=clf.fit(x_train, y_train)

# %%
pred_train=rgr.predict(x_train)
accuracy_score(pred_train, y_train)
# Out:
# 0.9481446241674596

# %%
y_test= test['bankrupted']
test= test.drop(columns=['bankrupted'])
x_test= test

# %%
pred_test=rgr.predict(x_test)
accuracy_score(pred_test, y_test)
# Out:
# 0.9403183023872679

# %%
feat_importances = pd.Series(rgr.feature_importances_, index=x_train.columns)
plt.figure(figsize=(10,10)) 
feat_importances.sort_values().plot(kind='barh',color='teal', title = 'Feature Importances')
#feat_importances.sort_values(ascending=False)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(C=1e5,class_weight='balanced')

# Create an instance of Logistic Regression Classifier and fit the data.
logreg.fit(x_train, y_train)
# Out:
# C:\Users\Hannah\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=100000.0, class_weight='balanced', dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred=logreg.predict(x_test)

# %%
accuracy_score(y_pred, y_test)
# Out:
# 0.5636604774535809

# %%
feature_importance = abs(logreg.coef_[0])
feature_importance = 100.0 * (feature_importance / feature_importance.max())
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5

# %%
featfig = plt.figure()
featax = featfig.add_subplot(1, 1, 1)
featax.barh(pos, feature_importance[sorted_idx], align='center', color= 'teal')
featax.set_yticks(pos)
featax.set_yticklabels(np.array(x_train.columns)[sorted_idx], fontsize=8)
featax.set_xlabel('Relative Feature Importance')

plt.tight_layout()   
plt.show()

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)
# Out:
# [[418 328]
#  [  1   7]]

# %% [markdown]
# ## Precision Recall Report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.56      0.72       746
#            1       0.02      0.88      0.04         8
#
#     accuracy                           0.56       754
#    macro avg       0.51      0.72      0.38       754
# weighted avg       0.99      0.56      0.71       754

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, logreg.predict(x_test))
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(x_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

# %%
# a =
# Out:
#   File "<ipython-input-64-828ec4a4fd72>", line 1
#     a =
#         ^
# SyntaxError: invalid syntax

# %%
df_bankrupt.drop_duplicates()
# Out:
#      COMPANY_FKEY  BANK_KEY SUBSID_NAME  BANKRUPTCY_TYPE  LAW_COURT_FKEY  \
# 1           19411       196         NaN               11             148
# 8          353827       534         NaN               11             108
# 10         356830      1164         NaN               11             133
# 11         357097      1155         NaN               11             108
# 12         704384      1054         NaN               11             110
# ..            ...       ...         ...              ...             ...
# 169       1330487      1397         NaN               11             108
# 171       1340752      1441         NaN               11             133
# 175       1355804      2285         NaN               11             108
# 177       1375098      2297         NaN               11             184
# 180       1397087      2303         NaN               11             108
#
#      COURT_TYPE_CODE                          COURT_NAME COURT_S_NAME  \
# 1                  1  New York Southern Bankruptcy Court       NY SBC
# 8                  1           Delaware Bankruptcy Court        DE BC
# 10                 1      Massachusetts Bankruptcy Court        MA BC
# 11                 1           Delaware Bankruptcy Court        DE BC
# 12                 1     Florida Middle Bankruptcy Court       FL MBC
# ..               ...                                 ...          ...
# 169                1           Delaware Bankruptcy Court        DE BC
# 171                1      Massachusetts Bankruptcy Court        MA BC
# 175                1           Delaware Bankruptcy Court        DE BC
# 177                1          Minnesota Bankruptcy Court        MN BC
# 180                1           Delaware Bankruptcy Court        DE BC
#
#      COURT_LOC_STREET  COURT_LOC_CITY  ... HIWATER_INCMST_NETINC_QTR_DATE  \
# 1                 NaN             NaN  ...                     2003-12-31
# 8                 NaN             NaN  ...                     2005-01-01
# 10                NaN             NaN  ...                     2007-06-30
# 11                NaN             NaN  ...                     2019-06-30
# 12                NaN             NaN  ...                     2010-09-30
# ..                ...             ...  ...                            ...
# 169               NaN             NaN  ...                     2007-12-28
# 171               NaN             NaN  ...                     2005-12-31
# 175               NaN             NaN  ...                     2008-12-31
# 177               NaN             NaN  ...                            NaN
# 180               NaN             NaN  ...                            NaN
#
#      HIWATER_INCMST_NETINC_QTR HIWATER_INCMST_NETINC_TTM_DATE  \
# 1                  499948000.0                     2004-09-30
# 8                          0.0                     2001-06-30
# 10                  16277000.0                     2000-08-31
# 11                  11743000.0                     2019-06-30
# 12                         0.0                     2010-09-30
# ..                         ...                            ...
# 169                        0.0                     2007-12-28
# 171                        0.0                     2007-12-31
# 175                        0.0                     2005-12-31
# 177                        NaN                            NaN
# 180                        NaN                            NaN
#
#      HIWATER_INCMST_NETINC_TTM HIWATER_INCMST_NETINC_FY_DATE  \
# 1                  567866000.0                    2003-12-31
# 8                   14600000.0                    2001-06-30
# 10                  -2816050.0                    2000-08-31
# 11                   3595000.0                    2000-12-31
# 12                  -8173000.0                    2010-09-30
# ..                         ...                           ...
# 169                  2326382.0                           NaN
# 171                -59825181.0                    2007-12-31
# 175                -10240000.0                    2005-12-31
# 177                        NaN                           NaN
# 180                        NaN                           NaN
#
#     HIWATER_INCMST_NETINC_FY NAME_CHANGE_DATE1 NAME_CHANGE_DATE2  \
# 1                499948000.0        2014-07-01        1996-02-14
# 8                        NaN               NaN               NaN
# 10                       NaN        2004-04-08               NaN
# 11                       0.0        2009-09-14        2001-08-22
# 12                       0.0        2001-05-16               NaN
# ..                       ...               ...               ...
# 169                      NaN        2007-11-15               NaN
# 171              -21654318.0               NaN               NaN
# 175                      0.0               NaN               NaN
# 177                      NaN        2006-10-13               NaN
# 180                      NaN               NaN               NaN
#
#     NAME_CHANGE_DATE3 bankrupt_year
# 1                 NaN          2003
# 8                 NaN          2005
# 10                NaN          2009
# 11                NaN          2009
# 12                NaN          2008
# ..                ...           ...
# 169               NaN          2010
# 171               NaN          2010
# 175               NaN          2010
# 177               NaN          2004
# 180               NaN          2009
#
# [82 rows x 465 columns]

# %%
relevant_columns = df_bankrupt[['COMPANY_FKEY','FILE_DATE']]
#list(df_bankrupt.columns)
df['cik'][:5]

# COMPANY_FKEY is CIK
df_bankrupt['COMPANY_FKEY'][:5]

df_bankrupt['COMPANY_FKEY'].nunique()

#filter for 2000-2010
mask = (pd.to_datetime(df_bankrupt['BANK_BEGIN_DATE']).dt.year >1999) &  (pd.to_datetime(df_bankrupt['BANK_BEGIN_DATE']).dt.year < 2011)

df_bankrupt_2000 = df_bankrupt[mask]

df_bankrupt_2000.head()
# Out:
#     COMPANY_FKEY  BANK_KEY SUBSID_NAME  BANKRUPTCY_TYPE  LAW_COURT_FKEY  \
# 1          19411       196         NaN               11             148
# 8         353827       534         NaN               11             108
# 10        356830      1164         NaN               11             133
# 11        357097      1155         NaN               11             108
# 12        704384      1054         NaN               11             110
#
#     COURT_TYPE_CODE                          COURT_NAME COURT_S_NAME  \
# 1                 1  New York Southern Bankruptcy Court       NY SBC
# 8                 1           Delaware Bankruptcy Court        DE BC
# 10                1      Massachusetts Bankruptcy Court        MA BC
# 11                1           Delaware Bankruptcy Court        DE BC
# 12                1     Florida Middle Bankruptcy Court       FL MBC
#
#     COURT_LOC_STREET  COURT_LOC_CITY  ... HIWATER_INCMST_NETINC_QTR_DATE  \
# 1                NaN             NaN  ...                     2003-12-31
# 8                NaN             NaN  ...                     2005-01-01
# 10               NaN             NaN  ...                     2007-06-30
# 11               NaN             NaN  ...                     2019-06-30
# 12               NaN             NaN  ...                     2010-09-30
#
#     HIWATER_INCMST_NETINC_QTR HIWATER_INCMST_NETINC_TTM_DATE  \
# 1                 499948000.0                     2004-09-30
# 8                         0.0                     2001-06-30
# 10                 16277000.0                     2000-08-31
# 11                 11743000.0                     2019-06-30
# 12                        0.0                     2010-09-30
#
#     HIWATER_INCMST_NETINC_TTM HIWATER_INCMST_NETINC_FY_DATE  \
# 1                 567866000.0                    2003-12-31
# 8                  14600000.0                    2001-06-30
# 10                 -2816050.0                    2000-08-31
# 11                  3595000.0                    2000-12-31
# 12                 -8173000.0                    2010-09-30
#
#    HIWATER_INCMST_NETINC_FY NAME_CHANGE_DATE1 NAME_CHANGE_DATE2  \
# 1               499948000.0        2014-07-01        1996-02-14
# 8                       NaN               NaN               NaN
# 10                      NaN        2004-04-08               NaN
# 11                      0.0        2009-09-14        2001-08-22
# 12                      0.0        2001-05-16               NaN
#
#    NAME_CHANGE_DATE3 bankrupt_year
# 1                NaN          2003
# 8                NaN          2005
# 10               NaN          2009
# 11               NaN          2009
# 12               NaN          2008
#
# [5 rows x 465 columns]

# %%
df_merge = pd.merge(df, df_bankrupt_2000, left_on = 'cik', right_on = 'COMPANY_FKEY', suffixes = ('_fundam', '_bank'), how = 'left')
df_merge['cik'].nunique()
# Out:
# 965

# %%
# df_merge_11 = df_merge[df_merge['BANKRUPTCY_TYPE']==11]
# df_merge_11

# %%
df_merge.head()
# Out:
#    GVKEY LINKPRIM LIID LINKTYPE  LPERMNO  LPERMCO      LINKDT   LINKENDDT  \
# 0   1177        P   01       LC  88845.0  41072.0  12/14/2000  11/30/2018
# 1   1177        P   01       LC  88845.0  41072.0  12/14/2000  11/30/2018
# 2   1177        J   03       NR      NaN      NaN  06/29/2001  01/31/2006
# 3   1177        P   01       LC  88845.0  41072.0  12/14/2000  11/30/2018
# 4   1177        P   01       LC  88845.0  41072.0  12/14/2000  11/30/2018
#
#      datadate   fyear  ... HIWATER_INCMST_NETINC_QTR_DATE  \
# 0  12/31/2000  2000.0  ...                            NaN
# 1  12/31/2001  2001.0  ...                            NaN
# 2  12/31/2002  2002.0  ...                            NaN
# 3  12/31/2003  2003.0  ...                            NaN
# 4  12/31/2004  2004.0  ...                            NaN
#
#   HIWATER_INCMST_NETINC_QTR HIWATER_INCMST_NETINC_TTM_DATE  \
# 0                       NaN                            NaN
# 1                       NaN                            NaN
# 2                       NaN                            NaN
# 3                       NaN                            NaN
# 4                       NaN                            NaN
#
#   HIWATER_INCMST_NETINC_TTM HIWATER_INCMST_NETINC_FY_DATE  \
# 0                       NaN                           NaN
# 1                       NaN                           NaN
# 2                       NaN                           NaN
# 3                       NaN                           NaN
# 4                       NaN                           NaN
#
#   HIWATER_INCMST_NETINC_FY NAME_CHANGE_DATE1 NAME_CHANGE_DATE2  \
# 0                      NaN               NaN               NaN
# 1                      NaN               NaN               NaN
# 2                      NaN               NaN               NaN
# 3                      NaN               NaN               NaN
# 4                      NaN               NaN               NaN
#
#   NAME_CHANGE_DATE3 bankrupt_year
# 0               NaN           NaN
# 1               NaN           NaN
# 2               NaN           NaN
# 3               NaN           NaN
# 4               NaN           NaN
#
# [5 rows x 1454 columns]

# %%
df_test = df_merge[df_merge['cik'] ==815508]

# %%
df_test.head()
# Out:
#        GVKEY LINKPRIM LIID LINKTYPE  LPERMNO  LPERMCO      LINKDT   LINKENDDT  \
# 5302  122315        P   01       LC  87057.0  16691.0  07/30/1999  07/21/2009
# 5303  122315        P   01       LC  87057.0  16691.0  07/30/1999  07/21/2009
# 5304  122315        P   01       LC  87057.0  16691.0  07/30/1999  07/21/2009
# 5305  122315        P   01       LC  87057.0  16691.0  07/30/1999  07/21/2009
# 5306  122315        P   01       LC  87057.0  16691.0  07/30/1999  07/21/2009
#
#         datadate   fyear  ... HIWATER_INCMST_NETINC_QTR_DATE  \
# 5302  10/31/2000  2000.0  ...                     2006-10-31
# 5303  10/31/2001  2001.0  ...                     2006-10-31
# 5304  10/31/2002  2002.0  ...                     2006-10-31
# 5305  10/31/2003  2003.0  ...                     2006-10-31
# 5306  10/31/2004  2004.0  ...                     2006-10-31
#
#      HIWATER_INCMST_NETINC_QTR HIWATER_INCMST_NETINC_TTM_DATE  \
# 5302                -6281000.0                     2009-04-28
# 5303                -6281000.0                     2009-04-28
# 5304                -6281000.0                     2009-04-28
# 5305                -6281000.0                     2009-04-28
# 5306                -6281000.0                     2009-04-28
#
#      HIWATER_INCMST_NETINC_TTM HIWATER_INCMST_NETINC_FY_DATE  \
# 5302               -14692330.0                    2008-10-28
# 5303               -14692330.0                    2008-10-28
# 5304               -14692330.0                    2008-10-28
# 5305               -14692330.0                    2008-10-28
# 5306               -14692330.0                    2008-10-28
#
#      HIWATER_INCMST_NETINC_FY NAME_CHANGE_DATE1 NAME_CHANGE_DATE2  \
# 5302                      NaN               NaN               NaN
# 5303                      NaN               NaN               NaN
# 5304                      NaN               NaN               NaN
# 5305                      NaN               NaN               NaN
# 5306                      NaN               NaN               NaN
#
#      NAME_CHANGE_DATE3 bankrupt_year
# 5302               NaN        2009.0
# 5303               NaN        2009.0
# 5304               NaN        2009.0
# 5305               NaN        2009.0
# 5306               NaN        2009.0
#
# [5 rows x 1454 columns]

# %%
mask = pd.to_datetime(df_merge['datadate']).dt.year + 1 == pd.to_datetime(df_merge['BANK_BEGIN_DATE']).dt.year

df_merge['bankrupted'] = np.where(mask, 1,0)

# %%
df_merge['bankrupted']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 7243    0
# 7244    0
# 7245    0
# 7246    0
# 7247    0
# Name: bankrupted, Length: 7248, dtype: int32

# %%
mask = pd.to_datetime(df_merge['datadate']).dt.year + 1 == pd.to_datetime(df_merge['BANK_BEGIN_DATE']).dt.year
df_merge[mask]
# Out:
#        GVKEY LINKPRIM LIID LINKTYPE  LPERMNO  LPERMCO      LINKDT   LINKENDDT  \
# 76      3171        P   01       LC  24548.0   5308.0  06/30/1982  07/20/2009
# 321    12879        C   01       NR      NaN      NaN  03/18/1999  07/31/2004
# 368    13071        P   01       NR      NaN      NaN  04/13/1995  02/13/2007
# 429    13282        C   01       LU  10928.0   8805.0  12/11/1986  08/20/2002
# 662    14581        P   01       LC  75580.0   9849.0  08/05/1988  09/30/2002
# 706    14836        P   01       LU  11895.0   9815.0  06/09/1988  10/21/2002
# 1032   23000        P   01       LC  89559.0  10716.0  11/19/2002  07/27/2005
# 1094   23799        P   01       LU  76880.0  10874.0  04/01/1991  01/30/2006
# 1249   24224        P   01       LU  76720.0  11004.0  06/28/1991  02/17/2006
# 1342   24402        P   01       NU      NaN      NaN  07/04/2003           E
# 1412   24668        P   01       NU      NaN      NaN  09/02/1999  10/29/2010
# 1461   24712        P   01       LC  77230.0  11205.0  11/14/1991  04/29/2003
# 1556   24858        P   01       NU      NaN      NaN  08/25/2000  07/31/2002
# 1652   25033        P   01       LC  85837.0  15964.0  02/12/1998  03/20/2009
# 2199   28699        P   01       LC  79518.0  12332.0  08/05/1993  07/31/2008
# 2537   30291        P   01       LU  80609.0  13131.0  06/07/1994  07/26/2002
# 2543   30361        C   01       LU  80612.0  13160.0  06/30/1994  03/05/2001
# 2586   30837        P   01       NU      NaN      NaN  08/16/2000  12/31/2002
# 2615   31037        C   01       LC  81051.0  30509.0  11/22/1994  10/01/2001
# 2690   31518        P   01       NU      NaN      NaN  06/30/2001  12/31/2013
# 2857   61167        P   01       NR      NaN      NaN  08/15/2008  04/30/2010
# 2908   61433        C   01       LU  82493.0  14067.0  10/19/1995  01/17/2002
# 3050   61673        P   02       NR      NaN      NaN  06/30/1998  05/31/2005
# 3302   62215        P   01       LU  83141.0  14383.0  02/21/1996  07/29/2003
# 3377   62465        N  01C       LX  85192.0  15570.0  07/02/1997  12/24/2009
# 3390   62497        P   01       NU      NaN      NaN  08/29/2002  05/31/2013
# 3483   62860        P   01       LC  83527.0  14625.0  05/15/1996  04/11/2003
# 3799   63430        C   01       LU  83816.0  31701.0  08/06/1996  01/22/2003
# 3839   63604        P   01       LU  83918.0  14965.0  09/20/1996  04/15/2005
# 3930   63882        P   01       NU      NaN      NaN  08/30/1996           E
# 3983   63990        P   01       NU      NaN      NaN  12/17/2002  09/30/2005
# 4151   64382        P   01       NR      NaN      NaN  06/13/2002  10/31/2003
# 4449   65709        P   01       NU      NaN      NaN  06/20/2001  10/31/2008
# 5252  121762        P   01       LU  87008.0  16617.0  06/29/1999  04/13/2004
# 5310  122315        P   01       LC  87057.0  16691.0  07/30/1999  07/21/2009
# 5381  125460        P   01       NU      NaN      NaN  10/29/1999  02/28/2002
# 5936  137803        P   01       LC  88432.0  37927.0  07/18/2000  01/05/2010
# 6015  138464        C   01       LC  88515.0  38416.0  08/03/2000  07/01/2003
# 6139  140042        P   01       NR      NaN      NaN  09/25/2008  07/05/2010
# 6180  140443        P   01       LC  88730.0  40203.0  10/12/2000  12/08/2008
# 6476  155614        P   01       LC  89860.0  44491.0  10/17/2003  05/11/2010
# 6525  157758        P   01       LC  90128.0  45084.0  04/16/2004  04/28/2008
# 6716  162956        P   01       LC  90945.0  47874.0  10/28/2005  11/03/2008
# 6839  166200        P   01       LC  91820.0  51809.0  02/02/2007  12/20/2010
#
#         datadate   fyear  ... HIWATER_INCMST_NETINC_QTR  \
# 76    12/31/2008  2008.0  ...                16277000.0
# 321   12/31/2001  2001.0  ...                  958488.0
# 368   10/31/2002  2002.0  ...                54265000.0
# 429   12/31/2001  2001.0  ...                       NaN
# 662   12/31/2001  2001.0  ...                 3423000.0
# 706   12/31/2001  2001.0  ...                       NaN
# 1032  12/31/2004  2004.0  ...                 6177300.0
# 1094  12/31/2005  2005.0  ...                       0.0
# 1249  12/31/2005  2005.0  ...                       0.0
# 1342  12/31/2005  2005.0  ...                       0.0
# 1412  12/31/2001  2001.0  ...                 8226000.0
# 1461  12/31/2002  2002.0  ...                       0.0
# 1556  12/31/2001  2001.0  ...                       NaN
# 1652  10/31/2008  2008.0  ...                       0.0
# 2199  12/31/2007  2007.0  ...                 4008000.0
# 2537  12/31/2001  2001.0  ...                       0.0
# 2543  12/31/2000  2000.0  ...                       NaN
# 2586  12/31/2001  2001.0  ...                       NaN
# 2615  12/31/2000  2000.0  ...                 3907000.0
# 2690  06/30/2008  2008.0  ...                 -368460.0
# 2857  12/31/2008  2008.0  ...                -2333077.0
# 2908  12/31/2001  2001.0  ...                       0.0
# 3050  12/31/2000  2000.0  ...                31749851.0
# 3302  12/31/2002  2002.0  ...                       0.0
# 3377  12/31/2008  2008.0  ...                24861000.0
# 3390  12/31/2007  2007.0  ...                       0.0
# 3483  12/31/2002  2002.0  ...                       NaN
# 3799  12/31/2002  2002.0  ...                       NaN
# 3839  12/31/2004  2004.0  ...                       0.0
# 3930  06/30/2002  2002.0  ...                  894187.0
# 3983  12/31/2002  2002.0  ...                       0.0
# 4151  12/31/2002  2002.0  ...                       0.0
# 4449  06/30/2001  2001.0  ...                       NaN
# 5252  12/31/2003  2003.0  ...                -4583000.0
# 5310  10/31/2008  2008.0  ...                -6281000.0
# 5381  02/28/2001  2000.0  ...                       NaN
# 5936  12/31/2008  2008.0  ...                -1286000.0
# 6015  12/31/2002  2002.0  ...                       NaN
# 6139  12/31/2008  2008.0  ...                10311000.0
# 6180  12/31/2007  2007.0  ...                -2401000.0
# 6476  12/31/2009  2009.0  ...                -3707251.0
# 6525  12/31/2007  2007.0  ...                -1617000.0
# 6716  09/30/2007  2007.0  ...                       0.0
# 6839  12/31/2009  2009.0  ...                       0.0
#
#      HIWATER_INCMST_NETINC_TTM_DATE HIWATER_INCMST_NETINC_TTM  \
# 76                       2000-08-31                -2816050.0
# 321                      2004-12-31                   16907.0
# 368                      2012-12-31                66310000.0
# 429                             NaN                       NaN
# 662                      2016-01-31                 4513000.0
# 706                             NaN                       NaN
# 1032                     2002-12-31                23445900.0
# 1094                     2001-01-31               -16397100.0
# 1249                     2002-12-31                14645000.0
# 1342                     2002-12-31                 9720000.0
# 1412                     2005-06-30                14886000.0
# 1461                     2004-12-31                14690013.0
# 1556                            NaN                       NaN
# 1652                     2001-10-31                -1985000.0
# 2199                     2002-12-31                 1950000.0
# 2537                     2000-12-31                 1150000.0
# 2543                            NaN                       NaN
# 2586                            NaN                       NaN
# 2615                     2012-03-28                24807600.0
# 2690                     2006-06-30                 -956090.0
# 2857                     1999-03-31               -10403678.0
# 2908                     1999-12-31                 -395316.0
# 3050                     2017-03-31                25656470.0
# 3302                     2000-12-31                12949465.0
# 3377                     2004-12-31                42474000.0
# 3390                     2007-12-28                19955482.0
# 3483                            NaN                       NaN
# 3799                            NaN                       NaN
# 3839                     2002-12-31                17314000.0
# 3930                     2006-06-30                  481625.0
# 3983                     1999-12-31                -5176000.0
# 4151                     2000-12-31               -48704000.0
# 4449                            NaN                       NaN
# 5252                     2001-12-31                -3440840.0
# 5310                     2009-04-28               -14692330.0
# 5381                            NaN                       NaN
# 5936                     2000-12-31               -31118500.0
# 6015                     2006-09-28                       0.0
# 6139                     2012-12-31                -7146000.0
# 6180                     2001-12-31               -12328400.0
# 6476                     2002-12-31               -14198000.0
# 6525                     2007-06-30               -18960000.0
# 6716                     2009-09-30                -8061727.0
# 6839                     2007-12-31               -59825181.0
#
#      HIWATER_INCMST_NETINC_FY_DATE HIWATER_INCMST_NETINC_FY NAME_CHANGE_DATE1  \
# 76                      2000-08-31                      NaN        2004-04-08
# 321                     2004-12-31                -162188.0               NaN
# 368                     2012-12-31               54265000.0        2006-11-21
# 429                            NaN                      NaN               NaN
# 662                     2015-10-31                1012000.0        2012-08-21
# 706                            NaN                      NaN               NaN
# 1032                    2002-12-31                      NaN        2001-03-02
# 1094                    2001-01-31                      NaN               NaN
# 1249                    2002-12-31                      NaN        2003-08-19
# 1342                    2002-12-31                      0.0               NaN
# 1412                    2008-12-28                      NaN               NaN
# 1461                    2004-12-31                      0.0               NaN
# 1556                           NaN                      NaN        2002-07-16
# 1652                    2001-10-31                      NaN               NaN
# 2199                    2002-12-31                      NaN        2008-09-22
# 2537                    2000-12-31                      0.0        1998-06-11
# 2543                           NaN                      NaN               NaN
# 2586                           NaN                      NaN        1996-09-11
# 2615                    2011-12-28                      NaN               NaN
# 2690                    2004-06-30                -368460.0        2000-01-14
# 2857                    1999-12-31               -2347239.0               NaN
# 2908                    1999-12-31                      0.0               NaN
# 3050                    2016-12-31                      0.0        2014-12-23
# 3302                    2000-12-31                      0.0               NaN
# 3377                    2004-12-31               24861000.0        2002-08-06
# 3390                    2007-12-28                      0.0        2008-02-04
# 3483                           NaN                      NaN        2001-08-14
# 3799                           NaN                      NaN        1999-04-16
# 3839                    2002-12-31                      NaN        2000-08-01
# 3930                    2006-06-30                 894187.0        2005-02-08
# 3983                    1999-12-31                      0.0        2004-02-13
# 4151                    2000-12-31                      0.0        1999-01-26
# 4449                           NaN                      NaN               NaN
# 5252                    2001-12-31                      NaN               NaN
# 5310                    2008-10-28                      NaN               NaN
# 5381                           NaN                      NaN               NaN
# 5936                    2000-12-31                      NaN        2010-01-05
# 6015                           NaN                      NaN               NaN
# 6139                    2012-12-31               -1375000.0        2007-08-17
# 6180                    2001-12-31                      NaN               NaN
# 6476                    2002-12-31                      NaN        2007-05-23
# 6525                    2007-12-31              -12695000.0               NaN
# 6716                    2009-09-30                      0.0               NaN
# 6839                    2007-12-31              -21654318.0               NaN
#
#      NAME_CHANGE_DATE2 NAME_CHANGE_DATE3 bankrupt_year bankrupted
# 76                 NaN               NaN        2009.0          1
# 321                NaN               NaN        2002.0          1
# 368                NaN               NaN        2003.0          1
# 429                NaN               NaN        2002.0          1
# 662                NaN               NaN        2002.0          1
# 706                NaN               NaN        2002.0          1
# 1032               NaN               NaN        2005.0          1
# 1094               NaN               NaN        2006.0          1
# 1249               NaN               NaN        2006.0          1
# 1342               NaN               NaN        2006.0          1
# 1412               NaN               NaN        2002.0          1
# 1461               NaN               NaN        2003.0          1
# 1556        1998-07-01               NaN        2002.0          1
# 1652               NaN               NaN        2009.0          1
# 2199               NaN               NaN        2008.0          1
# 2537               NaN               NaN        2002.0          1
# 2543               NaN               NaN        2001.0          1
# 2586               NaN               NaN        2002.0          1
# 2615               NaN               NaN        2001.0          1
# 2690               NaN               NaN        2009.0          1
# 2857               NaN               NaN        2009.0          1
# 2908               NaN               NaN        2002.0          1
# 3050        2014-10-08        2000-04-10        2001.0          1
# 3302               NaN               NaN        2003.0          1
# 3377               NaN               NaN        2009.0          1
# 3390               NaN               NaN        2008.0          1
# 3483               NaN               NaN        2003.0          1
# 3799               NaN               NaN        2003.0          1
# 3839               NaN               NaN        2005.0          1
# 3930        2002-07-02        1997-02-13        2003.0          1
# 3983        1996-06-25               NaN        2003.0          1
# 4151               NaN               NaN        2003.0          1
# 4449               NaN               NaN        2002.0          1
# 5252               NaN               NaN        2004.0          1
# 5310               NaN               NaN        2009.0          1
# 5381               NaN               NaN        2002.0          1
# 5936               NaN               NaN        2009.0          1
# 6015               NaN               NaN        2003.0          1
# 6139               NaN               NaN        2009.0          1
# 6180               NaN               NaN        2008.0          1
# 6476               NaN               NaN        2010.0          1
# 6525               NaN               NaN        2008.0          1
# 6716               NaN               NaN        2008.0          1
# 6839               NaN               NaN        2010.0          1
#
# [44 rows x 1455 columns]

# %%
df_merge['cik'].nunique()
# Out:
# 965

# %%
pd.to_datetime(df_merge['datadate']).dt.year + 1
# Out:
# 0       2001
# 1       2002
# 2       2003
# 3       2004
# 4       2005
#         ...
# 7243    2009
# 7244    2010
# 7245    2011
# 7246    2010
# 7247    2011
# Name: datadate, Length: 7248, dtype: int64

# %%
np.where()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-9ae2c456e86e> in <module>
# ----> 1 np.where()
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# TypeError: where() missing 1 required positional argument: 'condition'

# %%
pd.to_datetime(df_test['BANK_BEGIN_DATE']).dt.year

# %%
df_test['BANK_BEGIN_DATE']

# %%
df_merge.head()
